# %%
import nltk
import numpy as np
import csv
import pandas as pd
import seaborn as sns
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import matplotlib
from textblob import TextBlob
from matplotlib import pyplot as plt
# import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
stop_words = set(stopwords.words("english"))

# %%
data = pd.read_csv('hubspotCombined.csv')
print ("Original 'reviews_ioCombined.csv' CSV Data: \n")
data
# Out:
# Original 'reviews_ioCombined.csv' CSV Data:
#                                                 Review   Rating         Date
# 0    The integration is extremely easy to use and h...        4  Jan 11 2022
# 1    Yes makes it more difficult HubSpot help mostl...        1  Jan 11 2022
# 2    It works very well and integrates well with my...        5  Jan 10 2022
# 3    I use Missive to send email but they show as s...        2  Jan 10 2022
# 4    did not want every email to be in HubSpot but ...        1   Jan 7 2022
# ..                                                 ...      ...          ...
# 630  Working fine but HubSpot integration is very i...        2  Jul 13 2020
# 631  yet to see its benefits figuring out how to le...        5  Jul 13 2020
# 632  Logging/Tracking Gmail activity as a sales rep...        4  Jul 13 2020
# 633  The HubSpot-Gmail integration makes it easy to...        5  Jul 13 2020
# 634  If I have HubSpot integration turned on with m...        1  Jul 13 2020
#
# [635 rows x 3 columns]

# %%
comments = []
with open ("hubspotCombined.csv", "r", encoding ='utf-8') as file:
    reader = csv.reader(file)
    for row in reader:
        comments.append(row)
        print (row)
# Out:
# ['Review', ' Rating', ' Date']
# ['The integration is extremely easy to use and helpful with tracking deals as they move forward.', '4 ', 'Jan 11 2022']
# ['Yes makes it more difficult HubSpot help mostly consists if there is not much time left on call', '1 ', 'Jan 11 2022']
# ['It works very well and integrates well with my gmail calendar. It saves me having to pay an extra fee for this feature and helps my business grow.', '5 ', 'Jan 10 2022']
# ['I use Missive to send email but they show as sent in gmail but they arent being pulled into the deals in HS', '2 ', 'Jan 10 2022']
# ['did not want every email to be in HubSpot but wanted tracking and had to uncheck each time I sent an email', '1 ', 'Jan 7 2022']
# ['Funciona muy bien. Estable y muy confiable. Utilizamos la suite para toda la empresa con excelentes resultados', '5 ', 'Jan 7 2022']
# ['Works well means I can contact people straight from HubSpot. a good feature.', '3 ', 'Jan 5 2022']
# ['Gmail funciona muy bien su integración con HubSpot me genera demasiadas notificaciones y contactos que no necesito.', '3 ', 'Jan 4 2022']
# ['Todo muy bien funciona excelente te permite usar todas las funciones sin problema sin ningún tipo de irregularidad.', '5 ', 'Jan 4 2022']
# ['terrific slight bug with respect to saving contacts and contact recognition from calendly (instead of default calendly) but overall solid.', '5 ', 'Jan 4 2022']
# ['gmail is good but not as seamless as Office suite...integrations require all or nothing versus easily selectible copies going to HubSpot...main difficulty is in handling attachments...a bit clunky.', '3 ', 'Jan 4 2022']
# ['Está funcionando perfeitamente bem. Uma ótima ferramenta que tem inúmeras formas de conexão com outros aplicativos e facilita demais a vida.', '5 ', 'Jan 3 2022']
# ['hasta el momento muy bien se puede enlazar lo del CRM al gmail con lo cual no se escapa ninguna cadena de correos', '4 ', 'Jan 3 2022']
# ['Gmail is definitely working great for me. I would love to continue using Gmail for my day to day communication.', '5 ', 'Jan 3 2022']
# ['Have used other CRMs with better Gmail integration. The main thing missing here is a Deal status for each email in my Gmail Inbox without having to click through.', '3 ', 'Jan 3 2022']
# ['ez to use so far smooth reactive and ez to find and i like the edit features to add to notes', '5 ', 'Dec 31 2021']
# ['It is working very well. I was able to start using it quickly and it provides useful information in an organized format that I can customize.', '5 ', 'Dec 31 2021']
# ['login stuck in a loop it does not work login stuck in a loop it does not work login stuck in a loop it does not work', '1 ', 'Dec 30 2021']
# ['I like how my emails can automatically be tracked in HubSpot so that I can set task reminders to follow up with my prospects', '4 ', 'Dec 30 2021']
# ['Good! Keep up Good work .. Look forward for more Features & email capabilities', '4 ', 'Dec 30 2021']
# ['Wonderfully designed tool. Worth using it. It really helps a person to record all the transactions and helps great book keeping.', '5 ', 'Dec 30 2021']
# ['Muy bien es funcional es sencillo su uso y me sirve bastante. Lo puedo usar en la pc o en mi cel.', '4 ', 'Dec 29 2021']
# ['Excelente cumple con mis expectativas y con lo que busco realizar así que todo bien', '5 ', 'Dec 29 2021']
# ['it is easy to connect  still connecting and you can send in every moments what you need  and recive  what you what at all the time', '5 ', 'Dec 28 2021']
# ['The missing components are task management and sequence management. The seller has to flip between G-mail and HubSpot to get most things done.', '2 ', 'Dec 28 2021']
# ['Gmail and HubSpot work well together. This integration saves me a lot of time because I can easily use templates to respond to common emails and I like how easy it is to add my various meeting links.', '5 ', 'Dec 26 2021']
# ['I am simply pleased with Gmail. It is easy to use being available from any browser is probably the bigest advantage.', '5 ', 'Dec 24 2021']
# ['Has not been useful as it rarely ever remains signed in and as a result forgets to sync properly.', '1 ', 'Dec 24 2021']
# ['Easy to install and works well. Quick and simple installation. Intuitive interface.', '5 ', 'Dec 24 2021']
# ['It is very efficient. It helps with booking appointments / meetings easier...................', '5 ', 'Dec 23 2021']
# ['HubSpot is anything but intuitive.', '1 ', 'Dec 23 2021']
# ['Gmail works very well. I feel that It allows me to organize my schedule very well. I also feel like the organization in my inbox helps me filter a lot of my emails.', '5 ', 'Dec 22 2021']
# ['More or less ok. Time to time happening some errors with gmail. but ovelal ok.', '5 ', 'Dec 22 2021']
# ["Using HubSpot+Gmail has been amazing. Not only updates my pipeline with info regarding the communication it allows my team to keep track of contacts proposals deals and the bits and pieces of what it takes to manage sales and business development for a growing startup. It's perfect for a small team while adding a powerful resource to all involved.", '5 ', 'Dec 21 2021']
# ['.............asdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdf', '5 ', 'Dec 21 2021']
# ["Global access made easy Formatting and email attachment's are clear and formatted to the document.", '5 ', 'Dec 21 2021']
# ['Excelente hace tiempo intenté integrarla a mi cuenta de HubSpot y no funcionaba; ahora si es excelente el resultado.', '5 ', 'Dec 20 2021']
# ['The HubSpot Plugin is really helpful in bringing up contact information on the spot and allowing quick access to templates and snippets. However the plugin does a terrible job with Tracking emails and is always counting my email opens as an open by my prospect and lead so my data is not accurate for email opens.', '2 ', 'Dec 20 2021']
# ['Me gusta poder hacer carpetas con los diferentes emails y que se almacenen de manera correcta', '5 ', 'Dec 20 2021']
# ['otimo otimo otimo otimo otimo otimo otimo otimo otimo otimo otimo otimo otimo otimo', '5 ', 'Dec 17 2021']
# ['Funciona bien tienen buena relación entre HubSpot mail personal calendarios y actividades.', '5 ', 'Dec 17 2021']
# ['Es una herramienta básica e indispensable en mi área laboral. Para comunicación interne y externa.', '4 ', 'Dec 16 2021']
# ['Muy bien pero con la extension sirve más aun. Impactante lo de cerca que se pueden medir las campañas', '5 ', 'Dec 16 2021']
# ['Great! It was extremely easy to use. Tracking was nice and the automatic attachment of the communication to the contact was great.', '5 ', 'Dec 16 2021']
# ['It is working pretty well. I am excited to scale this now. I really love the automations.', '4 ', 'Dec 15 2021']
# ['lots of bugs on my Macbook Pro M1 lots of bugs on my Macbook Pro M1 lots of bugs on my Macbook Pro M1', '1 ', 'Dec 14 2021']
# ['All the official mails we can see and revert also with records. and save even though we forget password we can recover very easily.', '5 ', 'Dec 14 2021']
# ['abcdefghijklmnopqrstuhh"uiezyirh_fui"yegfy_yug"&ehz_pgd&b"uzajfgba"yuezkfyhzbufy"g\'eahb_yufhghe', '4 ', 'Dec 14 2021']
# ['Easy to install and use with HubSpot. I use to use Calendy with HubSpot. Based on easy of use with Gmail I will try using Google Calendar with HubSpot.', '5 ', 'Dec 13 2021']
# ['The activity tracker is not consistent or always effective. Some contacts are reading but I get no indications they are.', '2 ', 'Dec 13 2021']
# ['Permite tener varias herramientas en un solo lugar. Hace mas fácil el seguimiento de actividades', '5 ', 'Dec 12 2021']
# ['This integration really needs to support mobile for email logging and tracking.', '3 ', 'Dec 10 2021']
# ['O Gmail funciona muito bem com HubSpot. E podemos programar as resoluções e tarefas', '5 ', 'Dec 9 2021']
# ["Gmail works well. Very well. It's the integration with HubSpot that is sometimes distracting and not helpful.", '3 ', 'Dec 8 2021']
# ['Great reminder of what needs to be done and followed-up. Makes you rise above the competition who is not using such an CRM.', '4 ', 'Dec 8 2021']
# ['très bien mais je cherche le SAV HubSpot pour mes questions techniques - très bien mais je cherche le SAV HubSpot pour mes questions techniques', '4 ', 'Dec 8 2021']
# ['My emails are not being tracked in HubSpot even though I have tracking turned on.', '2 ', 'Dec 7 2021']
# ["sync works well from all devices mobile and desktop. It's important for me to have all activities on HubSpot", '5 ', 'Dec 7 2021']
# ['SuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuper', '5 ', 'Dec 7 2021']
# ['Gmail is fine. It does what I need from an email and a calendar. However getting the features that I value working with HS has been a challenge.', '2 ', 'Dec 6 2021']
# ['Sim pois usamos o Gmail tanto para entrar em contato com novos clientes quanto para responder as pessoas que já são nossos clientes.', '5 ', 'Dec 6 2021']
# ["Ca se désactive constamment. Du coup mon objectif n'est pas atteint. J'envoie des mails mais ils ne s'archivent pas", '2 ', 'Dec 6 2021']
# ['Gmail is challenging when you have a long thread of emails under the same topic. There is no clear view to see what is the most updated and how threads on the email are being answered.', '2 ', 'Dec 5 2021']
# ['Na minha opinião a ferramenta atende muito bem os fins propostos e o uso da ferramenta nos permite alcançar de maneira objetiva os resultados profissionais esperados.', '5 ', 'Dec 5 2021']
# ['If you want to track your emails create a sophisticated CRM and leverage your Sales Pipeline I recommend this product.', '5 ', 'Dec 3 2021']
# ['Easy to use great visibility in the contact and company record inside of HubSpot. A must have!', '5 ', 'Dec 2 2021']
# ['Excellent for ease of use. 5 Stars across the board. I really like the 2 layer security.', '5 ', 'Dec 2 2021']
# ['Excelente herramienta de apoyo diario para recibir y enviar información necesario para realizar trabajos', '5 ', 'Dec 1 2021']
# ['Gmail é meu provedor padrão tem funcionado muito bem. As atualizações são bem rápidas', '5 ', 'Dec 1 2021']
# ["Gmail is a great tool. I'm so glad to have it as part of my arsenal of resources!", '5 ', 'Dec 1 2021']
# ['better with out HubSpot extra work to go back and forth cannot access from my phone so not want another app on my phone', '1 ', 'Dec 1 2021']
# ['Its a great app but for some reason its broken for me. Does not integrate with Gmail well', '3 ', 'Dec 1 2021']
# ['Me gusta que desde la aplicación se pueda crear y registrar el correo y se pueda ver el historial desde aqí al igual que se puede visualizar la aparturas clics de mis correos y los documentos que le envío', '5 ', 'Nov 30 2021']
# ["Using HubSpot to track all your sales & customer emails is fantastic. Records get updated and you have a great information about your communications. The one major major issue is that you have to be really careful about tracking emails because you can end up with a pile of contacts in HubSpot that shouldn't be there. And worse you can end up with legal investor and other emails & documentation inside HubSpot for others to see. HubSpot needs to make it easier to filter out contacts that you don't want to track. It is possible to do this it just isn't easy.", '2 ', 'Nov 29 2021']
# ['funciona perecto facilita mucho mi gestión diaria en el proceso de ventas .', '5 ', 'Nov 29 2021']
# ['Easy to use and set up - works well. Really please with how straightforward is was to set up with Gmail (which we used already) can now easily track all communication associated with each deal', '5 ', 'Nov 29 2021']
# ["working very well for us so far. We are only 2 weeks in though so there's still time :P", '5 ', 'Nov 29 2021']
# ["It's working well and I will continue to use it more often with my prospects.", '4 ', 'Nov 26 2021']
# ['That is none of your concern.....................................................', '3 ', 'Nov 26 2021']
# ['ça marche super bien je recommande ça a changé ma vie bien entendu hahahahah', '5 ', 'Nov 24 2021']
# ['Gmail est un outil facile à prendre en main et facile gérable sur plusieurs supports que ce soit le téléphone ou le PC - il a une grande accessibilité et a en plus un belle capacité de stockage de données ce qui facilite les échanges de data sans perte de qualité.', '3 ', 'Nov 24 2021']
# ['this is major for seeing how the email is being received and responded to from the sender', '3 ', 'Nov 24 2021']
# ["It is working well - I need to be better at using it's functionality and features.", '4 ', 'Nov 24 2021']
# ['Good. However we need a better way to total the number of emails that are made on a daily weekly etc basis.', '4 ', 'Nov 23 2021']
# ['L\'extension Gmail HubSpot permet de suivre et d\'enregistrer les échanges prospects et clients facilement. La fonction "ne jamais enregistrer" permet de conserver la maîtrise sur sa création de nouveaux contacts. De quoi garder son CRM propre.', '5 ', 'Nov 23 2021']
# ['Extensão funcionando após instalação ajuda no processo de vendas e nosso time comercial.', '5 ', 'Nov 22 2021']
# ['Was and is fairly easy to learn both tools; and to utilize different aspects of both to coordinate my daily tasks.', '4 ', 'Nov 22 2021']
# ['Excelente calidad facilidad manejo sencillo alta capacidad de integración', '5 ', 'Nov 22 2021']
# ['I like that I can access the CRM and assets directly from Gmail (Snippets Templates etc).', '5 ', 'Nov 22 2021']
# ['Gmail me es muy funcional y práctico pero la vinculación con HubSpot no es tan sencilla de aprender sobre todo cuando no se desea que todos los correos (contactos) tengan esta vinculación', '3 ', 'Nov 20 2021']
# ['It was not working. But your team put up with my fears of communications and got the job done.', '5 ', 'Nov 19 2021']
# ['Funciona muy bien y permite un manejo de la informacion muy dianamico por lo tanto excelente aplicacion', '5 ', 'Nov 19 2021']
# ['The integration failed to capture all emails being sent. Not able to track down why.', '2 ', 'Nov 18 2021']
# ['Es fácil de manejar y muy intuitivo. Me ayuda a controlar mejor el seguimiento de mis correos y también a redactarlos de mejor forma.', '5 ', 'Nov 18 2021']
# ['using Gmail I can connect all y others email accounts and and a only one view', '5 ', 'Nov 18 2021']
# ["Gmail offre à ses utilisateur une facilité d'utilisation avec une multitude de fonctionnalités pratiques et gratuit.", '2 ', 'Nov 17 2021']
# ["It's great and it is easy to use I am able to easily see whom opened my email and when.", '4 ', 'Nov 17 2021']
# ['I have multiple email address and I am using Spark to combine it all. It also has calendar extension and now I have to use also chrome and gmail on the side.', '1 ', 'Nov 17 2021']
# ['Gmail is great but for some reason even when I open my inbox I get alerts showing my recipient opened the mail.', '3 ', 'Nov 17 2021']
# ['Tudo funciona mt bem porém não consigo fazer de forma fácil com que um e-mail que eu recebi por fora do HubSpot volte a ter sua cadência por aqui. Por exemplo se eu mando uma mensagem pelo Hub e copio dois destinatários porém um deles clicar em "responder só para mim"', '5 ', 'Nov 16 2021']
# ['I enjoy the functionality. I used calendly for years and it never worked well with other programs.', '4 ', 'Nov 16 2021']
# ['Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good and Good.', '4 ', 'Nov 16 2021']
# ["When creating a Meeting on HubSpot it not only added it to my Google Calendar but it shared it with my client's including all of my notes (that I thought would be private). To avoid this I just removed Google from HubSpot so that booking meetings on HubSpot does not email my clients. I will just manually add meetings to my Google Calendar.", '1 ', 'Nov 16 2021']
# ['I have multiple Gmail addresses that fully integrate with my HubSpot account. Making it super easy to associated contacts with the various emails that get sent.', '5 ', 'Nov 16 2021']
# ["HubSpot's Gmail plugin is an effective way to send and track emails to customers prospects team members and vendors. Highly recommend it.", '5 ', 'Nov 16 2021']
# ['funciona bien  es fácil de usar e ingresar la es amigable con mi conexiones', '5 ', 'Nov 16 2021']
# ['It is great tool to communicate with leads. Very easy to use and has lot of other tools which helps the sales people. For example Google search calendar Google meet.', '5 ', 'Nov 16 2021']
# ['We are on Google Workspace so Gmail is the logical solution. It works great for us. It would be great to access my personal Gmail emails in HubSpot too like in PipeDrive. It would make answering non-shared-inbox emails so much easier in HubSpot.', '4 ', 'Nov 16 2021']
# ['Working well for me and the business regarding the e-mail services will recommend to others', '5 ', 'Nov 16 2021']
# ["HubSpot's integration with Gmail just doesn't stack up against many (most?) of the other sales engagement and automation platforms.", '2 ', 'Nov 15 2021']
# ["joe@me.net wants some insurance. I add him to HubSpot and can track my calls and emails to Joe. I will get other emails from underwriting@insuranceco.com and applicationreceived@insuranceco.com some of which I will want to attach to Joe or (Joes 100k policy Deal) (others of course from those same emails need to be attached to mary@me.net or susy@me.net) this requested feature has had good feedback in the HubSpot community boards but has not been implemented. Other than that you'll be hooked if you dip you feet in and use the product. It will help you track all those things spead between your calendar your email your sms and your call log all those things that are slipping between the cracks and losing you deals.", '3 ', 'Nov 15 2021']
# ['Excelente parceria entre as empresas. Só temos a criar mais sinergia. Estamos trilhando uma jornada de inovação e tecnologia', '4 ', 'Nov 13 2021']
# ['Gmail really works excellent on my business transactions. So precise on time and very helpful.', '5 ', 'Nov 13 2021']
# ['Gmail is a very efficient instrument for our company. The integration with HubSpot helps managing better the relations with our clients and stay on top of everything.', '5 ', 'Nov 12 2021']
# ['Die Erweiterung setzt sich "oben auf GMail" und zerstört die Nutzererfahrung an vielen Stellen. Insbesondere indem sie den Fokus klaut. Dadurch löst man aus versehen shortcuts aus und löscht mails. Sehr problematisch.', '2 ', 'Nov 11 2021']
# ["Overall it has been good. Good integration with other software I am using. HubSpot experience was horrible though. It's the worst a CRM can offer.", '1 ', 'Nov 11 2021']
# ['email tracking helps provide insight and clarity into past customer/prospect interactions. snippets and templates save loads of time. meeting links too! all of these features are intuitive and easy to access within Gmail.', '5 ', 'Nov 10 2021']
# ['Toda nossa comunicação fica integrada a plataforma deixando o histórico das tratativas em nosso contato e/ou negócio.', '5 ', 'Nov 10 2021']
# ['Es muy intuitivo y eso me gusta bastante es muy fácil de usar y no he tenido problema alguno en su uso.', '4 ', 'Nov 10 2021']
# ['MUY BIEN YA QUE DA LA FACILIDAD DE COMUNICACIÓN Y ADJUNTAR FORMATOS SOLICITADOS', '4 ', 'Nov 10 2021']
# ['Correcto. El tener integrado el aviso de tareas en ambas aplicaciones me hace avanzar en el día a dia.', '5 ', 'Nov 10 2021']
# ["It is frustrating to me when I get error messages but I can't see what the error is. There is one error message with 5 listed reasons of why you might have received the error.", '2 ', 'Nov 9 2021']
# ['Funciona muy bien para poder comunicar los correos que se envian en el uso de los recordatorios por ejemplo.', '4 ', 'Nov 9 2021']
# ['HubSpot plug in shows up on gmail but the emails are not logged/synced in HubSpot.', '1 ', 'Nov 9 2021']
# ['Overall is working pretty well the only thing that I find slightly troublesome is the fact that it does not remain pinged nor does it maintain the window opened for calendars for instance.', '4 ', 'Nov 9 2021']
# ['Muy bien tenemos la facilidad de comunicarnos con los clientes y con nuestro equipo de una forma rápida', '5 ', 'Nov 9 2021']
# ['Gmail es un aliado más que una herramienta la gran mayoría de empresas con las cuales interactuamos lo tienen y eso facilita no solo videollamadas sino también el trabajo colaborativo.', '5 ', 'Nov 8 2021']
# ['If I had a choice I would dump HubSpot and get Salesforce. HubSpot has yet to be helpful to me without lots of headaches.', '1 ', 'Nov 8 2021']
# ['It works well. We used some shitty program called Goldmine before (think windows outlook 2005)...', '4 ', 'Nov 8 2021']
# ['Fehlerfrei manchmal gibt es Aussetzer aber das ist normal kein Server hat 100% Uptime', '3 ', 'Nov 8 2021']
# ['This is a "must have" for me. All e-mail are linked to the company and the contact.', '5 ', 'Nov 7 2021']
# ['Muy familiarizado con gmail y con laplataforma google suite empresarial y personal', '5 ', 'Nov 6 2021']
# ['Agilidad en los procesos y facilidad de uso en los diferentes apps que tiene gmail.', '5 ', 'Nov 5 2021']
# ['Gmail is mission critical for our company and my personal work life. I use it for many applications in all areas of my life.', '5 ', 'Nov 5 2021']
# ['Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien', '4 ', 'Nov 4 2021']
# ['The overall integration works well but I suggest to integrate the tasks too', '4 ', 'Nov 3 2021']
# ['Comes Easy to use and has a lot of features. Using it to track the conversation and email to lead generation. Must have for everyone!', '5 ', 'Nov 3 2021']
# ['Todo el tiempo se desvincula de mi gmail. Y debo logiarme nuevamente...................', '2 ', 'Nov 3 2021']
# ["C'est notre boite pro mais elle n'a pas l'air parametrable pour l'instant.", '1 ', 'Nov 3 2021']
# ['The integration between Gmail and HubSpot is working extremely well thank you!', '5 ', 'Nov 3 2021']
# ["It's okay but should have more features and be quicker to use. I'd like to see whether an email was opened without opening it myself.", '2 ', 'Nov 3 2021']
# ['Funciona genial es una herramienta útil y muy eficaz de comunicación para los usuarios', '5 ', 'Nov 2 2021']
# ['good no time to write in details................................................', '5 ', 'Nov 2 2021']
# ['Nice integration overall. I like having my emails at my fingertips in HubSpot.', '4 ', 'Nov 2 2021']
# ['Es una plataforma mucho más amigable y facil de usar. Facil de configurar y personalizar.', '5 ', 'Nov 2 2021']
# ['HubSpot is probably the best help desk service available in the market right now and their support is awesome! The navigation is simple and easy to use. Overall a much better experience than Zendesk.', '5 ', 'Nov 2 2021']
# ['Gmail is use for communication service complaints services management Lots of mail are for advertising purpose after Unsubsribe the mails are frequently comes with another titles.', '2 ', 'Nov 1 2021']
# ['mi empresa asido muy funcional y mas que a hora contamos con su nueva herramienta de trabajo', '5 ', 'Oct 29 2021']
# ["Gmail itself is going well -- it's not really a personal choice more that we have subscribed to Google Workspace as a business and that comes with gmail.", '5 ', 'Oct 28 2021']
# ['Sim o Gmail atende a minha a necessidade por enquanto não tenho um volume de demanda.', '5 ', 'Oct 28 2021']
# ['Ótima ágil e eficiente. Me ajuda no dia a dia na comunicação com novos prospects.', '5 ', 'Oct 28 2021']
# ['Works well if you want all mail to be controlled by HubSpot but falls down when only some mail is to be managed - even if no mail is to be managed.', '2 ', 'Oct 28 2021']
# ['Con la vinculación de Gmail y HubSpot el seguimiento con los clientes se queda guardado no importa si se contesta desde Gmail o HubSpot el seguimiento se queda guardado. Me encanta que desde Gmail esta vinculada la empresa y así puedo acceder rápidamente a la empresa en HS', '5 ', 'Oct 28 2021']
# ['Browser-based email is the f-ing worst interface. Bring back command line!', '1 ', 'Oct 27 2021']
# ['Sim. Com o uso do Gmail traz muita facilidade pois conseguimos ter um acesso quase único junto ao HubSpot.', '5 ', 'Oct 27 2021']
# ['Estoy acostumbrada porque es mi cuenta personal adicional a que tienes todo el ecosistema de calendario reuniones y contactos. Esta integración de plataformas mejora la agilidad en las actividades diarias.', '5 ', 'Oct 27 2021']
# ['Espectacular la experiencia con HubSpot. Nos ha permitido automatizar nuestro trabajo. Espero pronto unir mas herramientas del sistema.', '5 ', 'Oct 26 2021']
# ["I would say is bad because I'm missing tickets from my customers. Emails do not reach HubSpot!", '2 ', 'Oct 26 2021']
# ['Gmail in Google Workspace works pretty well and I love it. Itegration with HubSpot is easy set in HubSpont Email settings', '5 ', 'Oct 26 2021']
# ['This is a must-use integration for HubSpot & Gmail clients. It is one of my main sales tools and a true g-d send.', '5 ', 'Oct 25 2021']
# ['I love to know what the team is up to and to be able to arrange meeting and keep record of all meetings in HubSpot.', '5 ', 'Oct 25 2021']
# ['It is simple to use. It is direct. easy to manage and setup in a way that works for our business.', '4 ', 'Oct 25 2021']
# ['Funktioniert sehr stabil. Ich bin zufrieden. Lediglich die Erstellung von Aufgaben in Gmail direkt könnte noch etwas flexibler gestaltet sein.', '5 ', 'Oct 25 2021']
# ['me parace todo lo que por el momento se haces va bastante bien. Para poder dar una valoración más concreta debo seguir aprendiendo a usar todas las funcionalidades posibles. En base a esto debep decir que los correos con tips de com usar tanto HubSpot como gmail son excelentes.', '4 ', 'Oct 25 2021']
# ['Fair nothing special hard to get answers to questions help and support weak', '3 ', 'Oct 22 2021']
# ['Perfeitamente não tenho o que reclamar do gmail conectado ao HubSpot. Até o momento tem me atendido demais', '5 ', 'Oct 22 2021']
# ['Funciona muy bien es una excelente herramienta la cual es compatible con varias herramientas', '5 ', 'Oct 22 2021']
# ['Ojalá podiera uno seleccionar qué correos son para enrutar y cuáles no. Quisiera saber también más de HubSpot ya que solo lo he usado una vez.', '3 ', 'Oct 21 2021']
# ['Gmail is ok. HubSpot still trying to learn the ins and outs of it and how ity works with my Ion Capital Solutions business', '3 ', 'Oct 21 2021']
# ['Gmail es una herramienta fácil de utilizar para gestión de correos. El agregar utilidades de monitoreo de comunicaciones apoya la gestión de la comunicación y diseño de estrategias a partir de la información.', '4 ', 'Oct 21 2021']
# ['Buena  pero mejorable. Hay muchas funciones que no son faciles de ajustar  igual creoque la ayuda existe y no la he buscado lo suficiente', '4 ', 'Oct 21 2021']
# ['No information to fix HubSpot - Gmail fix limited only to some overarching general guides. Documentation is poor. Driving our organisation crazy.', '1 ', 'Oct 21 2021']
# ['0. horrible. affects negatively tremendously. no support whatsoever!!I i have been trying to get help by all means but nobody answer me. please help me asap. thanks!', '1 ', 'Oct 20 2021']
# ['All working fine for my needs. Simple to use and understand when training others to use.', '5 ', 'Oct 20 2021']
# ['Sim está funcionando normalmente. Muito bom esse aplicativo.. Melhor experiência', '5 ', 'Oct 20 2021']
# ['This review is specifically for Gmail integration with SalesHub and not HubSpot overall. My work is done primarily within Gmail and you are not auto-alerted within Gmail in a user-friendly way. You have "open" SalesHub to see a list of relevant activities/opens/clicks etc.. instead of being able to see them in Gmail. Also the reporting features are very limited and you cannot "batch enroll" a list of leads/contacts. SalesHub caps at 50 contacts -- not very efficient... Compared to MixMax and SalesLoft -- SalesHub significantly falls short of being a sales-centric tool.', '1 ', 'Oct 20 2021']
# ['Algunas funciones no se encuentran habilitadas. El espacio de la firma electronica es mayor al del cuerpo del correo', '4 ', 'Oct 19 2021']
# ['Gmail and G Suite work very well for us on the whole. Only issue is deeply nested messages are not easy to work with', '4 ', 'Oct 19 2021']
# ['Task reminders notifications through Gmail is a real added value compare to other CRMs (eg SalesForce)', '5 ', 'Oct 19 2021']
# ['Fine................................................................................', '3 ', 'Oct 18 2021']
# ["In general HubSpot is a helpful tool for sales. However the Gmail integration could be more user-friendly especially (at least in my case) tagging email threads to specific projects. I'm having trouble locating the correct project. An auto-fill search feature that works is all I need. I have multiple projects per vendor/contact so that may lead to confusion.", '3 ', 'Oct 18 2021']
# ['Can track notes and e-mails and any communication that was had in one spot. Makes it easier to follow up on calls as well as set up tasks...weekly', '4 ', 'Oct 18 2021']
# ['excelente herramienta solución simple e intuitiva favorece el cierre de ventas', '5 ', 'Oct 18 2021']
# ['Me funciona bien me da facilidades en el seguimiento de los correos dentro de la empresa.', '5 ', 'Oct 18 2021']
# ['Muy bien facilita el trabajo en gran medida y ofrece una linea de conexión con los clientes. Está muy bien integrado y quizas falta poder sincronizar la firma en lugar de ponerla en cada sitio por separado', '5 ', 'Oct 18 2021']
# ['Funciona bien y la incidencia ha sido muy positiva como complemento al resto de herramientas.', '4 ', 'Oct 18 2021']
# ["I have a lot of ideas on how this could improve. I use it every day. It's just not everything I want it to be. It's close but its just not quite there.", '3 ', 'Oct 17 2021']
# ['I have a lot of meetings and having them pop up and easy to access through slack saves a lot of clicking.', '5 ', 'Oct 16 2021']
# ['Bien me está ordenando. Falta un poco de claridad en la asistencia técnica', '4 ', 'Oct 15 2021']
# ['Gmail is brilliant. I love the tools and apps I can add to it to creat my workspace.', '5 ', 'Oct 14 2021']
# ["It's been difficult to go from SFDC to HubSpot to be honest. the template editing is not great neither as it does not refresh", '2 ', 'Oct 14 2021']
# ['The perfect application! EVERRYTHING YOU NEED IS AT THE TIP OF YOUR HANDS! I LOVE HOW IT CREATES TEMPLATES AFTER IT NOTICES YOU COPYING AND PASTING! IT IS A PHENOMENAL APP!', '5 ', 'Oct 14 2021']
# ['Gmail is a bit delayed in syncing with HubSpot ( when a lead is assigned). which might be critical when a direct demo is associated to one contact.', '3 ', 'Oct 14 2021']
# ['Creo que el funcionamiento es bueno y el hecho de que esté ligado a HubSpot es genial pero creo que le añadiría funciones como por ejemplo el poder incluir "tarea" en el email o poder incluir las plantillas que tenemos en HubSpot desde gmail. Estas 2 funciones estaría bien tenerlas diponibles igual que está disponible la casilla de "seguimiento".', '4 ', 'Oct 14 2021']
# ['Great to be able to be in HubSpot or Gmail and move freely between the two', '4 ', 'Oct 13 2021']
# ['We will never look back We are very happy with the choice we made as a business to proceed with this service.', '5 ', 'Oct 13 2021']
# ['Funciona bien y me permite crecer en mi negocio.Porque con las nuevas funcionalidades se logra mas productividad.', '5 ', 'Oct 13 2021']
# ['Gmail works fine. HubSpot messages end up not reaching the target audience. Why do I need 75 characters for feedback? It is terrible', '1 ', 'Oct 13 2021']
# ['great CRM very extensive in capability... I am only an employee as a user and this CRM is very good at helping to guide my outbound calls and prospecting each day. Additionally- it seems great for reports that my employer needs to monitor as well.', '5 ', 'Oct 12 2021']
# ['Personalmente prefiero trabajar con otro software que permita trabajar con carpetas (folders). Con el gmail trabajar y archivar con carpetas es muy incómodo porque es un árbol que se despliega con el paso del mouse en una ventana muy pequeña para mi forma de trabajo', '2 ', 'Oct 12 2021']
# ['tres simple d utilisation', '2 ', 'Oct 12 2021']
# ['Fine with Google Chrome G-Mail and HubSpot to connect. I would like to know how to find Schedule Task to HubSpot.', '5 ', 'Oct 11 2021']
# ['Improved my sales process completely by integrating my HubSpot CRM into Gmail.', '5 ', 'Oct 11 2021']
# ['Es practico de usar me sirven mucho las plantillas para enviar mensajes a los clientes', '5 ', 'Oct 10 2021']
# ['IT is helping me receive more connections. I have been able to book more meetings using gmail with HubSpot than my last CRM', '4 ', 'Oct 8 2021']
# ['Does not work on Mozilla Firefox. I use Firefox through choice and this contractual stitch-up means that I am having to use two different browsers at once.', '2 ', 'Oct 8 2021']
# ['we do not have gmail we use microsoft', '5 ', 'Oct 7 2021']
# ["Gmail and Google Docs are a daily fundamental for our small business. Add to those the ease of use of our Youtube channel and it's a huge win for us.", '5 ', 'Oct 7 2021']
# ['Working really well! The automated integration makes it easy to log Emails and conversations.', '5 ', 'Oct 7 2021']
# ["I'm having problems with saving the emails and attachments into the deals when I'm receiving them", '3 ', 'Oct 7 2021']
# ["The Gmail integration works very well. I set it up years ago and often forget it's not just a part of Gmail!", '4 ', 'Oct 6 2021']
# ['SE TRABAJA MUY BIEN CON LA PLATAFORMA Y GMAIL LA INTEGRACION ES MUY BUENA Y SENCILLA DE USAR', '5 ', 'Oct 6 2021']
# ['WISELY DESIGNED VERY SENSITIVE TO GMAILVERY RICH IN DATA VERY VERY VERY GOOD', '5 ', 'Oct 6 2021']
# ['Reduce time and effort on email communication data exchange tracking customer actions building a customer profile', '5 ', 'Oct 6 2021']
# ['Bien. Es una buena integración me encanta enviar un mail y verlo todo en HubSpot luego', '4 ', 'Oct 5 2021']
# ['buena herramienta buena herramienta buena herramienta buena herramienta buena herramienta buena herramienta.', '4 ', 'Oct 5 2021']
# ['100 % perfect wont change as its important for so many features see above', '5 ', 'Oct 4 2021']
# ['Random. Los contactos y las empresas no son generados sistemáticamente y eso genera desconfianza. Puede que deje de usar HubSpot.', '2 ', 'Oct 4 2021']
# ['Gmail works well for us and meets all expectations. Ease of use connection to other applications pricing.', '5 ', 'Oct 2 2021']
# ['Gmail is fine. HubSpot is fine. But the two don’t work together well from a phone or IPad. I have to put in a bcc or forward code to get HubSpot to log my emails sent from gmail. Also why can’t I attach a file to an email sent from HubSpot?', '2 ', 'Oct 1 2021']
# ['Muy bien me ha funcionado acorde a mis necesidades tiene una buena interface.', '5 ', 'Oct 1 2021']
# ['Gmail has always been great. Have never had a problem with Gmail or google products.', '2 ', 'Oct 1 2021']
# ['I get multiple notifications on my phone that someone opened my emails but in many cases I know I am getting the notifications late or incorrectly. I know this because for awhile it was sending me notifications that my boyfriend was opening a email repeatedly but he said he was not. And from clients I will get like 10 notifications that they opened an email and I doubt that they opened it 10 times. And I wish that when I sent an email directly from my gmail HubSpot would let me know if someone clicked any of the links. That would be helpful.', '3 ', 'Oct 1 2021']
# ['5 stars hands down. The notification and interface are stellar and easy to use and figure out.', '5 ', 'Sep 30 2021']
# ['Funciona bastante bien puedo encontrar todo lo necesario con facilidad de modo a responder a la demanda de los clientes', '5 ', 'Sep 30 2021']
# ['I love it the time it saves me on logging communications and emails is amazing...', '5 ', 'Sep 30 2021']
# ['Not satisfied at all. Frustrated with functionality. Stopped my outreaching altogether', '1 ', 'Sep 29 2021']
# ["Grateful to have this integration but much could be improved. Would like to see more automatic triggering of syncing new email chains with contacts in HubSpot (not having to remember to BCC a random email address). I'd also like to see more control over which new contacts are created in HubSpot (i.e I don't want emails to non-leads to end up in HubSpot).", '2 ', 'Sep 29 2021']
# ['O gmail está funcionando muito bem pra mim tanto com agendas quanto com o calendário. Com essa integração eu diminuo o meu tempo de manuseio em tarefas repetitivas e tenho menos perdas de oportunidades em agendamentos com a facilidade do link de reuniões - e o melhor sem custo para a minha empresa que ainda é pequena e precisa desse dinheiro em outros lugares.', '5 ', 'Sep 29 2021']
# ['Funciona perfectamente y la integración es muy buena . Muy fácil de usar  intuitiva. Me gusta que además notifica cuando abren un correo', '5 ', 'Sep 29 2021']
# ['It is working great. It would be great if there was integration with the native mac mail system as this is what I was using but it has not been too difficult to run gmail for biofab through a web browser. it is definitely worth doing that to have the HS plug in there.', '5 ', 'Sep 28 2021']
# ['I love the plugin. It is really the key feature of HubSpot for me. The min 7', '4 ', 'Sep 28 2021']
# ['ITS ME NOW I havent taken the time to truly give it a shot .. This system takes time that takes me away from selling', '3 ', 'Sep 27 2021']
# ['não consigo integrar o email por isso não consigo beneficiar da integração que existe entre as duas marcas', '1 ', 'Sep 27 2021']
# ['Funciona bien el seguimiento y el registro de los contactos. Sin embargo de un tiempo para acá cada vez que envío un correo desde Gmail la extensión de HubSpot hace que se copie mi correo (Del cual estoy enviando) en cco y llega como copia a la bandeja de entrada lo cual es sumamente desesperante. Intenté desintalar la extención y sin ella funciona normal lo que quiere decir que es un problema de la extención de HubSpot. Intente ver en el blog de usuarios y hablar con un asesor pero no consigo la solución.... Muy triste', '2 ', 'Sep 27 2021']
# ['Duas grandes ferramentas que não fico sem em meu negócio. Muito bom e útil os recursos disponíveis.', '5 ', 'Sep 27 2021']
# ['Great alternative to connecting your inbox to HubSpot when you want to pick and choose what gets recorded.', '5 ', 'Sep 24 2021']
# ['GMAIL funciona bem sim. o tracking de mensagens de email relacionados com tickets HubSpot e negocios abertos não funciona bem', '3 ', 'Sep 24 2021']
# ['WOW so easy to use. You can easily add people to sequences use snippets and I love the open receipts that I get. If you use google just get the integration.', '5 ', 'Sep 24 2021']
# ['i can access work anywhere instead of installing outlook in my personal devices', '5 ', 'Sep 24 2021']
# ['Using HubSpot with Gmail is a deterrent to our business efficiency. It would behoove HubSpot to seek closer integration with other email platforms to see greater adoption from teams that must prioritize task allocation and operations through integrated communications over marketing and sales.', '2 ', 'Sep 23 2021']
# ["Default option to send to HubSpot must be OFF. Instead it's by default ON thus all my personal emails also sometimes ends up in HubSpot.", '1 ', 'Sep 23 2021']
# ["It's really nice. It allows me to schedule emails / sync all communication and allows me to easily change properties directly from the right side panel", '5 ', 'Sep 22 2021']
# ['Efficient Great Easy to use Able to organize everything Wish Google groups was this way', '5 ', 'Sep 22 2021']
# ['This combination is perfect it helps me understand what is going on with the email I sent after it left my side. :)', '5 ', 'Sep 22 2021']
# ['It integrates well and its a lot of improvement comparing just to couple years back esspecialy working with different accounts simultaneously', '5 ', 'Sep 22 2021']
# ['una información mas eficiente xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx', '5 ', 'Sep 22 2021']
# ['Gmail is not only mail program. It whole communication centre which helps keep all in one place.', '4 ', 'Sep 21 2021']
# ['Mala hace cosas que no quiero que haga y no es claro como deje de hacer lo que uno no quiere', '2 ', 'Sep 21 2021']
# ["It ended up creating an entire company record for the 3rd party that was not necessary and I can't cleanly merge it in with my original client record", '2 ', 'Sep 21 2021']
# ['.......................................................................................', '5 ', 'Sep 21 2021']
# ["It's great. Love that any communication sent is tracked on a contacts record on HubSpot", '5 ', 'Sep 21 2021']
# ['xgfjfgjfghfhgfghfghfghfghfghfghdfserwersdshyjukytyuytuyfghghffgdfgddfgdsdgsdgsdfsdfsdfsdfh', '5 ', 'Sep 20 2021']
# ['Emails that were recorded in early September are now missing. Can someone please find them?', '1 ', 'Sep 20 2021']
# ['Gmail works great HubSpot in this instance is garbage literally it has me worrying about who received a personal email from me that would be a contact in HubSpot now up to 13 recipients when I only sent it to 4 people wtf!!!', '1 ', 'Sep 20 2021']
# ['It great so far! I am getting used to it and the integration with HubSpot is really something which added more features.', '4 ', 'Sep 20 2021']
# ['Its good Its goodIts goodIts goodIts goodIts goodIts goodIts goodIts goodIts goodIts goodIts good', '5 ', 'Sep 17 2021']
# ['NA - There was NO call from HubSpot at the arranged time....................', '1 ', 'Sep 17 2021']
# ["Sometimes when I answer to an email on Gmail it doesn't sync directly with HubSpot and I have to log it manually.", '3 ', 'Sep 16 2021']
# ["It has been good but the HubSpot attachement creates contacts from a person's email domain. should be an option to select an account to attach.", '4 ', 'Sep 16 2021']
# ['Es la herramienta de trabajo que utilizamos en la empresa de trabajo para cotizar y estar en contacto con los clientes', '1 ', 'Sep 15 2021']
# ['Very nice! I am very please with the HubSpot and Gmail integration easy to use and lots of functionality. Reliable too!', '5 ', 'Sep 15 2021']
# ['Es el mail por preferencia pero no tiene ninguna diferenciación de otras . Es simplemente la que utilizamos.', '3 ', 'Sep 14 2021']
# ['me funciona a la perfección no me gusta que no tenga como agrupar por carpetas mis correos y que lleguen directamente a esa carpeta los correos seleccionados eso me daría mas orden a la hora de ver mi correo.', '5 ', 'Sep 14 2021']
# ['positivamente para cumplir con los requerimientos y las metas establecidas', '5 ', 'Sep 14 2021']
# ['It makes it easier to do my job on a daily basis. I find it helpful and easy to use.', '4 ', 'Sep 13 2021']
# ['Helps with tracking and organization. Ease of searching and finding emails through keywords.', '4 ', 'Sep 13 2021']
# ['En general funciona bien y me da cobertura a la mayoría de las necesidades que tengo en comunicación.', '5 ', 'Sep 13 2021']
# ["The hub spot GMail integration didn't work for me it said I don't have an email account associated with", '1 ', 'Sep 12 2021']
# ['Reply Emails Not Tracked. Wished They Were. When sending emails thru HubSpot the original email seems to contain tracking info but subsequent replies to the same thread dont seem to auto-integrate and need to be logged manually. not sure if this is the case or if we are just using the features incorrectly.', '2 ', 'Sep 10 2021']
# ['Tricky to manage Tickets by using emails. easy to track emails by using HubSpot plugin', '3 ', 'Sep 10 2021']
# ['This is one of the better Gmail integrations out there. All emails can be tagged if you want to track them if yes the contact gets created in HubSpot existing contacts the mail is linked as a communication history. You can tag the email to be linked to contact deal and/or organization. Amazing tool to keep track of communication history.', '5 ', 'Sep 10 2021']
# ["I don't know how I would function without this integration. I've used both gmail and outlook and I would say that the outlook plugin is more useful mainly because I'm able to easily schedule new tasks while in gmail. There is some room for improvement however.", '4 ', 'Sep 9 2021']
# ['Did not integrate Gmail to hubs pot kdkdkdkdkdkkdkdkdkdkdkkdkdkdkdkkdkdkkdkdkdk', '1 ', 'Sep 9 2021']
# ["However for me personally at least 90% of the emails I'm sending out aren't in interest for the HubSpot plugin. I'm missing a feature where every time I write an email HubSpot isn't automatically set to track and log every email but instead I would have to add this when relevant.", '2 ', 'Sep 9 2021']
# ["It often is a company process to ensure everyone is making their correspondence visible to the rest of the company. In previous years most CRMs would allow this by bcc'ing a set address. This wasn't ideal  people forget these rules so the gmail integration makes this foolproof", '5 ', 'Sep 7 2021']
# ['Did not work at all. Could Not Properly Integrate with the companies contact list.', '1 ', 'Sep 7 2021']
# ["Gmail is the best emailing service and it's FREE! Couldn't be happier with the integration of Gmail.", '5 ', 'Sep 7 2021']
# ['It works great BUT you should use the GMail extension (which I had to figure out myself) or EVERYTHING from Gmail will end up in HubSpot.', '4 ', 'Sep 7 2021']
# ['I installed HubSpot and I use it along side my Gmail it seems to work very well.', '5 ', 'Sep 7 2021']
# ['Está a funcionar muito bem. Estou muito satisfeita com o Gmail e também com o HubSpot. Duas áreas que se complementam na perfeição.', '5 ', 'Sep 6 2021']
# ['Gmail funciona perfectamente rápido y con seguridad no tengo problema en ese sentido', '1 ', 'Sep 3 2021']
# ['The Gmail/HubSpot integration is super helpful - use templates tracking follow-up task creation and much more.', '5 ', 'Sep 3 2021']
# ['Pela metade apenas os e-mails que envio pelo HubSpot ficam registrador o contrario não.', '2 ', 'Sep 2 2021']
# ['It makes it very efficient to be able to work directly from HubSpot or from Gmail and switch as needed while missing nothing in the paper trail.', '5 ', 'Sep 2 2021']
# ["Google Workspaces works just fine. But I don't like the HubSpot integration all that well because I feel that it relies on too much additional plugins. For example if I want good email tracking I have to use a Chrome extension to get the job done or send all emails from within HubSpot. Otherwise I have to manually BCC my HubSpot address each time. That is not the ideal solution for me because I prefer using Firefox and I don't want to have two tabs open for redundancy. Furthermore I do not receive all mail in HubSpot. Let me actually integrate HubSpot with Gmail without jumping through so many hoops.", '3 ', 'Sep 2 2021']
# ['Ha sido genial la facilidad de uso la integración con correos y reuniones nos ha permitido hacer un seguimiento efectivo a nuestros clientes.', '5 ', 'Sep 2 2021']
# ['Me parece excelente herramienta para el control general de los sistemas de CRM de la empresa', '5 ', 'Sep 2 2021']
# ['Everything now takes longer and is not able to use on Mac Mail or Mac Outlook which is disastrous. Please fix.', '2 ', 'Sep 2 2021']
# ['O serviço é muito excelente. Obrigada pelas funcionalidades liberadas para nós clientes HubSpot.', '5 ', 'Sep 2 2021']
# ['As ferramentas Google são excelentes. Sugiro ao HubSpot liberar um campo a mais para ser editável na hora de marcar a reunião.', '5 ', 'Sep 2 2021']
# ['Works perfectly with HubSpot. Love the all my HS tools are available to use out of gmail.', '5 ', 'Sep 2 2021']
# ['una buena aplicacion sin embargo le hace falta mas fucnionalidades.............', '4 ', 'Sep 1 2021']
# ['Gmail works very well with powerful features and few limitations: however HubSpots integration disables some of those features (e.g scheduled send) and is generally resource heavy causing Gmail to choke and become unstable. The logging and tracking options are sometimes unreliable appearing to track when set not to.', '3 ', 'Sep 1 2021']
# ...
# ["I like HS for what it can do but am not happy with what it won't do. The options are great but it's all or nothing. There really has to be automation friendly options for email integration. I don't need spam email infecting my HS account.", '2 ', 'May 25 2021']
# ["I love google products and haven't tried any other email services for my business or personal use. I'm biased for sure.", '5 ', 'May 25 2021']
# ['excellent for my type of work typically good integration with extension of other apps but for a while now the HB extension started having an annoying side window pop up that i could deactivate - had to remove the extension to stop it from popping up at every email. its closing button was also overlapping with other gmail buttons and made it impossible to turn it off', '2 ', 'May 25 2021']
# ['HubSpot integration of Gmail is a definite improvement over regular Gmail. It is now part of my routine.', '5 ', 'May 24 2021']
# ["it's free which is a maasive bonus it's helpful to be able to add leads immediately add a task or deal too. I wish it was possible to edit the details in gmail too like you can with the intercom + HubSpot integration", '5 ', 'May 24 2021']
# ['I will rate poor for overall my experience with HubSpot and will not recommend to anyone My experience is literally worst with HubSpot tool', '1 ', 'May 24 2021']
# ['Excelente de las mejores aplicaciones para trabajar muy intuitiva Fácil de entender y muy simple de usar Tiene herramientas gratuitas que apoyan mi trabajo', '5 ', 'May 24 2021']
# ["Gmail works well I don't like that some of my messages from someone I get mail from on a daily basis is put in the Social or Promotions folders.", '4 ', 'May 23 2021']
# ["It allows me to be more productive because I don't have to duplicate task and contact information", '4 ', 'May 23 2021']
# ['Gmail is easiest to navigate easy it is to use it seems like anything you need is right there at your fingertips plus all the hundreds and thousands if not millions of extensions and this all makes it very smooth to run a business with.', '2 ', 'May 22 2021']
# ['muy bien para la empresa es apropiado y logra que optimicemos nuestro tiempo y recursos.', '5 ', 'May 21 2021']
# ['excelente herramienta para la elaboración de campañas y marketing digital recomiendo mucho la herramienta', '5 ', 'May 21 2021']
# ['booohooo jhbouifhhjsvhn;aijupiwejhbchjbdxkjn yigtiuyhjikh yuguiyhoijh;juih yguighjki', '3 ', 'May 21 2021']
# ['The integration features with Gmail allow me to gain the visibility and insights I need to make informed decisions as it relates to my prospects and their ultimate decision making. Putting together new documentation is a breeze.', '5 ', 'May 21 2021']
# ['Es un correo mundial y muy funcional de fácil operación y ameno para enviar correos', '4 ', 'May 21 2021']
# ['positivamente a afectado la operación de ventas de la empres. Pero tengo dudas de como aumenta el conteo de si se abrió el correo.', '4 ', 'May 21 2021']
# ['The pop out on the right of the page needs to have a stop function it opens on every new email and takes up too much of the screen. I understand the benefits of it but it would be better to have the choice to use it or not. It takes up too much space on the page especially if you have the email page layout in two columns.', '2 ', 'May 21 2021']
# ["impossibilitato a controllare il numero di aperture di un'email o dell'allegato all'interno come fossi su HubSpot funzionalità parziali", '2 ', 'May 21 2021']
# ['Es läuft alles super gut und bin Super Zufrieden mit HubSpot +Gmail. Kann es nur Weiterempfehlen.', '5 ', 'May 21 2021']
# ["HubSpot's GMail integration is pretty seamless and makes it incredibly convenient to log/track emails. It's particularly helpful when sending proposals to potential clients so we can see in real time when they are opening and know when to do appropriate follow-up.", '4 ', 'May 20 2021']
# ['O Gmail funciona muito bem e junto com o HubSop só veio agregar valor! Facilidade para quem utiliza e muito bom para a empresa acompanhar o andamento do trabalho de seus funcionários.', '5 ', 'May 20 2021']
# ['it helps me to store a bulk of data under one roof. no need of any extra crm', '5 ', 'May 20 2021']
# ['Muy bien ha acelerado nuestro servicio y ha mejorado nuestra realcion con nuestros clientes', '5 ', 'May 20 2021']
# ['Es universal confiable de facil acceso y compatible e', '5 ', 'May 19 2021']
# ['Gmail ha sido una herramienta fundamental para el negocio pero la integración entre ambas plataformas deja mucho que desear. No es sencilla y en últimas resulta mejor buscar y enviar todo desde el mismo gmail y no HubSpot', '3 ', 'May 19 2021']
# ["Works great except for those few times the emails don't get integrated. It allows me to send emails quicker without having to leave the platform.", '3 ', 'May 19 2021']
# ['Muy bien se gestionan mejor lo contactos y las conversaciones y es muy fácil de usar', '4 ', 'May 19 2021']
# ['As you can expect from an email service like Yahoo Gmail you can use it in Outlook or standalone mine is integrated into the company structure', '4 ', 'May 19 2021']
# ['Excellent! It has made me well-organized! I feel confident stress-free & relaxed using it.', '5 ', 'May 19 2021']
# ['Es una buena integración aunque en pocasiones se desconecta o por alguna razon no se vuelcan los emails al 100%  no es facil filtrar aquellos emails que no deben volcarse pero esto depende mas de HubSpot que de Gmails.', '3 ', 'May 19 2021']
# ['La integración con HubSpot es muy básica y algunos correos no migran. (aun con la extensión prendida)', '2 ', 'May 18 2021']
# ['Works efficiently and allows https://www.gend.co to quickly log gmail conversations and sales outreach with our contact records.', '4 ', 'Mar 11 2021']
# ['somente sincroniza na primeira vez............................................................', '1 ', 'Mar 2 2021']
# ['Esta funcionando de maravilla ya que me ha dado los soportes necesarios para interactuar con mis clientes.', '5 ', 'Dec 21 2020']
# ["Works great with HubSpot. Can email from both gmail and HubSpot. The emails auto-log to the lead's profile in HubSpot and I can see if my prospect opened or clicked on any links. I can also use the templates sequences documents and my calendar links directly in Gmail.", '5 ', 'Dec 21 2020']
# ["Basic options don't work. Some options like having your signature in your email have been disabled. So you cant have your signature. Which is kind of important when sending prospects emails. Not impressed at all", '1 ', 'Dec 18 2020']
# ['It works fine when it stays logged in. Every other day I have to log back into the HubSpot tool.', '2 ', 'Dec 17 2020']
# ["I have 3 different businesses that all use Gmail and I figured that since I have each one connected (in HubSpot) to a HubSpot account using that email address that it wouldn't send email from one account to another but it does. It doesn't matter what account you link in HubSpot if you are logged in to a specific HubSpot account (which it forces when you are in Gmail) then all other Gmail accounts open that have the plugin will send emails to that HubSpot account. This is very bad for me.", '2 ', 'Dec 17 2020']
# ['Not well switching hosting to windows within the next quarter. For now we are not using the integration to its full potential.', '3 ', 'Dec 17 2020']
# ['Para mi personalmente es muy practico. Para el trabajo muy útil y seguro.', '5 ', 'Dec 17 2020']
# ['Easy to use suits well in the plateform and allow to me to have a general overview of all my activities', '5 ', 'Dec 17 2020']
# ['既存の連絡先を全て潜在顧客として捉えることが可能となるので、 新しいビジネスチャンスにつながります。 また、操作も簡単ですので質の良いコンタクトをどんどん追加していけます', '4 ', 'Dec 17 2020']
# ['Gmail und HubSpot funktionieren zusammen leider nicht gut. Mein Team und ich bitten daher dringenst um eine Integration in Mac Mail.', '1 ', 'Dec 17 2020']
# ['I want the ability to choose how I log in and not get the feeling I have to use gmail. HubSpots is nice but needs improvement especially on who review my email great idea but not there yet', '2 ', 'Dec 17 2020']
# ['funciona bien respuesta rápida fácil manejo en general. facilita el agendamiento.', '5 ', 'Dec 17 2020']
# ['Es simplemente la mejor herramienta que hemos encontrado para gestionar los correos corporativos de la empresa', '5 ', 'Dec 16 2020']
# ["I'd looked for a solution that allowed all the emails sent and received to a particular client to be stored in a neat and easy way along with notes call logs meetings etc to keep on track of everything. Gmail integrates with HubSpot seamlessly it even handles aliases pretty well which I wasn't expecting.", '5 ', 'Dec 16 2020']
# ['Gmail integration is wonderful as I can see real time alerts regarding prospects opening and viewing emails sent. It is also adds ease of attaching marketing material to send to prospects.', '5 ', 'Dec 16 2020']
# ['Muy bien me brinda una experiencia bastante agradable conectando funcionalidades de HubSpot en mi Gmail.', '5 ', 'Dec 16 2020']
# ["great helps to track the emails easier and faster to log the customers' information in the HubSpot", '5 ', 'Dec 16 2020']
# ["It's a great tool and one that we find very helpful both for ourselves and for our clients. However we run into issues with users who have multiple HubSpot accounts and wish to log different emails to different accounts. It would be great if there was a way within both gmail and outlook for you to toggle/select which HubSpot account you want to log each email to.", '3 ', 'Dec 16 2020']
# ['Me es útil y práctico en todo lo que hago día a día puedo ver todo lo relacionado con mis actividades', '4 ', 'Dec 15 2020']
# ['Excelente es muy útil su integración con Google Workspace. Hace el trabajo y seguimiento realmente práctico', '5 ', 'Dec 14 2020']
# ['Perfectly we use it as our communication channel within the company and it works perfectly. As well as our communication channel with outbound leads we want to prospect and to evangelize with our solution. It has been really useful and we have managed to capture the interest of leading companies in different industries.', '4 ', 'Dec 14 2020']
# ['Great additional to be able to track all incoming/outgoing emails for sales leads. It also automatically adds new contacts which is a huge time saver.', '5 ', 'Dec 14 2020']
# ['Gmail is awesome. Cannot do without it! It stores my documents for any time referencing and is user friendly.', '5 ', 'Dec 13 2020']
# ["Our company is having explosive growth. I love being able to see everything that I've sent my love having the templates I love Tracking my emails love the signature part is really nothing that I don't like about Gmail except that it doesn't have G mass and I love it together with hub spot so perfect I which hotspot was a little cheaper let the but it", '5 ', 'Dec 12 2020']
# ['PARA MI HA SIDO UNA BUENA OPCIÓN CONTAR CON GMAIL POR QUE DE MI CORREO CORPORATIVO COPIO A ESTE Y LA INFORMACIÓN QUEDA RESPALDADA.', '5 ', 'Dec 11 2020']
# ['Love the plug-in but it needs to support creating new tickets too. Currently it only allows linking to existing tickets. There should be an option to create a new ticket as well that is linked to the email and the contact.', '5 ', 'Dec 11 2020']
# ['In my opinion there could be more documentation related to the usage of the extension as it has excellent features and functions that can be discovered by using the tool but not from a document outlining them for people who have never had the chance to experiment with it.', '5 ', 'Dec 10 2020']
# ["Gmail is great. It is a much better solution for email then competitors that rely on POP or IMAP or Outlook/Exchange. The big problem with the integration of HS with Gmail is that there is still a lot of manual effort to bring data into HS. This isn't state of the art compared to other CRM tools on the market.", '3 ', 'Dec 10 2020']
# ['Gmail isolated is very good and the HubSpot tracking is less advanced when it comes to overview of tracking per email in G-mail/HubSpot extension and total view of campaigns etc in HubSpot - have a look at Mixmax for improvement suggestions ;-). I would strongly recommend to allow to import stand-alone mailing list from .CSV in HubSpot sequences.', '3 ', 'Dec 10 2020']
# ['Really helpful and saving time. All organised well in one place and the mail tracking works really good', '5 ', 'Dec 10 2020']
# ['4. La explicación es pesima en un espectacular producto. Es soportable pero no deberia permitirse. En general la explicaciones son deficiente y la curva es dolorosa', '5 ', 'Dec 9 2020']
# ['My team is able to see contact activities and reach out or not to specific contact according to my previous messages. Moreover the widget for Gmail helps me speed up the writing process by selecting snippets and templates directly into Gmail.', '5 ', 'Dec 7 2020']
# ['super tous les mails sont automatiquement envoyés sur HubSpot à partir de ma messagerie', '5 ', 'Dec 2 2020']
# ["it's working great easy to use and working as I intended. Only that it's actually add-on is a bit off-putting but not terrible", '4 ', 'Nov 26 2020']
# ['I would really like the HubSpot extension to work but had to disable until the problem can be overcome. I use the mail search function a lot.', '2 ', 'Oct 9 2020']
# ['1) I would like HubSpot to retire the legacy Chrome Extension in favor of a Google G-Suite Gmail Addon. The extension sits on top of the native UI overlaying other components and never works quite right frequently causing issues when trying to send messages through Gmail. 2) When you publish the addon please make sure it has the ability to create tickets. One use-case for this would be to click on a HubSpot addon in Gmail to forward messages that were sent to individual address (instead of the support address) and this functionality would allow us to create a ticket on behalf of the original sender.', '3 ', 'Sep 26 2020']
# ['There is one big problem with Gmail-HubSpot arrangement- It is not possible to sync contacts. It would be very convenient to have all the contacts I add to HubSpot populate in Gmail because it is very annoying to have contacts in two different places.', '3 ', 'Aug 3 2020']
# ["Gmail seems to work well. HubSpot email tracking doesn't work that well. email tracking within HubSpot is atrocious as it doesn't handle contacts tied to multiple deals. it simply guesses and is a huge time suck to clean up deals that have multiple contacts or contacts with multiple deals associated with him/her. This takes so much time to clean this up and get it sorted out.", '2 ', 'Jul 15 2020']
# ['The HubSpot Gmail integration does not meet my expectations at all. This is the capability I like least about HubSpot and the only thing I really miss about our previous CRM system.', '2 ', 'Jul 14 2020']
# ['And even the non-techies like me can get it working so that emails log to the HubSpot CRM easily.', '5 ', 'Jul 14 2020']
# ['Working fine but HubSpot integration is very intermittent. Sometimes works mostly not. Also the way HubSpot displays email threads is so annoying it’s almost a showstopper. You click on an email to some more and it leaps off in an entirely disorienting way somehow positioning the thread upside down so you have no idea what order to read anything in. It sucks', '2 ', 'Jul 13 2020']
# ['yet to see its benefits figuring out how to leverage the integration and with time we hope to know more about it.', '5 ', 'Jul 13 2020']
# ['Logging/Tracking Gmail activity as a sales rep goes saves the rep time and provide "activity" visibility across our company.', '4 ', 'Jul 13 2020']
# ['The HubSpot-Gmail integration makes it easy to engage and serve clients. All the email functions (snippets templates meetings and sequences) are available in the familiar Gmail interface.', '5 ', 'Jul 13 2020']
# ['If I have HubSpot integration turned on with my business account and accessed my personal account any email i send from the personal account the HubSpot plugin picks it up and logs it in HubSpot or sends it to the default email address of the business. This is a major security flaw.', '1 ', 'Jul 13 2020']

# %%
review = comments[0]
print (review)
# Out:
# ['Review', ' Rating', ' Date']

# %%
del comments[0]
comments
# Out:
# [['The integration is extremely easy to use and helpful with tracking deals as they move forward.',
#   '4 ',
#   'Jan 11 2022'],
#  ['Yes makes it more difficult HubSpot help mostly consists if there is not much time left on call',
#   '1 ',
#   'Jan 11 2022'],
#  ['It works very well and integrates well with my gmail calendar. It saves me having to pay an extra fee for this feature and helps my business grow.',
#   '5 ',
#   'Jan 10 2022'],
#  ['I use Missive to send email but they show as sent in gmail but they arent being pulled into the deals in HS',
#   '2 ',
#   'Jan 10 2022'],
#  ['did not want every email to be in HubSpot but wanted tracking and had to uncheck each time I sent an email',
#   '1 ',
#   'Jan 7 2022'],
#  ['Funciona muy bien. Estable y muy confiable. Utilizamos la suite para toda la empresa con excelentes resultados',
#   '5 ',
#   'Jan 7 2022'],
#  ['Works well means I can contact people straight from HubSpot. a good feature.',
#   '3 ',
#   'Jan 5 2022'],
#  ['Gmail funciona muy bien su integración con HubSpot me genera demasiadas notificaciones y contactos que no necesito.',
#   '3 ',
#   'Jan 4 2022'],
#  ['Todo muy bien funciona excelente te permite usar todas las funciones sin problema sin ningún tipo de irregularidad.',
#   '5 ',
#   'Jan 4 2022'],
#  ['terrific slight bug with respect to saving contacts and contact recognition from calendly (instead of default calendly) but overall solid.',
#   '5 ',
#   'Jan 4 2022'],
#  ['gmail is good but not as seamless as Office suite...integrations require all or nothing versus easily selectible copies going to HubSpot...main difficulty is in handling attachments...a bit clunky.',
#   '3 ',
#   'Jan 4 2022'],
#  ['Está funcionando perfeitamente bem. Uma ótima ferramenta que tem inúmeras formas de conexão com outros aplicativos e facilita demais a vida.',
#   '5 ',
#   'Jan 3 2022'],
#  ['hasta el momento muy bien se puede enlazar lo del CRM al gmail con lo cual no se escapa ninguna cadena de correos',
#   '4 ',
#   'Jan 3 2022'],
#  ['Gmail is definitely working great for me. I would love to continue using Gmail for my day to day communication.',
#   '5 ',
#   'Jan 3 2022'],
#  ['Have used other CRMs with better Gmail integration. The main thing missing here is a Deal status for each email in my Gmail Inbox without having to click through.',
#   '3 ',
#   'Jan 3 2022'],
#  ['ez to use so far smooth reactive and ez to find and i like the edit features to add to notes',
#   '5 ',
#   'Dec 31 2021'],
#  ['It is working very well. I was able to start using it quickly and it provides useful information in an organized format that I can customize.',
#   '5 ',
#   'Dec 31 2021'],
#  ['login stuck in a loop it does not work login stuck in a loop it does not work login stuck in a loop it does not work',
#   '1 ',
#   'Dec 30 2021'],
#  ['I like how my emails can automatically be tracked in HubSpot so that I can set task reminders to follow up with my prospects',
#   '4 ',
#   'Dec 30 2021'],
#  ['Good! Keep up Good work .. Look forward for more Features & email capabilities',
#   '4 ',
#   'Dec 30 2021'],
#  ['Wonderfully designed tool. Worth using it. It really helps a person to record all the transactions and helps great book keeping.',
#   '5 ',
#   'Dec 30 2021'],
#  ['Muy bien es funcional es sencillo su uso y me sirve bastante. Lo puedo usar en la pc o en mi cel.',
#   '4 ',
#   'Dec 29 2021'],
#  ['Excelente cumple con mis expectativas y con lo que busco realizar así que todo bien',
#   '5 ',
#   'Dec 29 2021'],
#  ['it is easy to connect  still connecting and you can send in every moments what you need  and recive  what you what at all the time',
#   '5 ',
#   'Dec 28 2021'],
#  ['The missing components are task management and sequence management. The seller has to flip between G-mail and HubSpot to get most things done.',
#   '2 ',
#   'Dec 28 2021'],
#  ['Gmail and HubSpot work well together. This integration saves me a lot of time because I can easily use templates to respond to common emails and I like how easy it is to add my various meeting links.',
#   '5 ',
#   'Dec 26 2021'],
#  ['I am simply pleased with Gmail. It is easy to use being available from any browser is probably the bigest advantage.',
#   '5 ',
#   'Dec 24 2021'],
#  ['Has not been useful as it rarely ever remains signed in and as a result forgets to sync properly.',
#   '1 ',
#   'Dec 24 2021'],
#  ['Easy to install and works well. Quick and simple installation. Intuitive interface.',
#   '5 ',
#   'Dec 24 2021'],
#  ['It is very efficient. It helps with booking appointments / meetings easier...................',
#   '5 ',
#   'Dec 23 2021'],
#  ['HubSpot is anything but intuitive.', '1 ', 'Dec 23 2021'],
#  ['Gmail works very well. I feel that It allows me to organize my schedule very well. I also feel like the organization in my inbox helps me filter a lot of my emails.',
#   '5 ',
#   'Dec 22 2021'],
#  ['More or less ok. Time to time happening some errors with gmail. but ovelal ok.',
#   '5 ',
#   'Dec 22 2021'],
#  ["Using HubSpot+Gmail has been amazing. Not only updates my pipeline with info regarding the communication it allows my team to keep track of contacts proposals deals and the bits and pieces of what it takes to manage sales and business development for a growing startup. It's perfect for a small team while adding a powerful resource to all involved.",
#   '5 ',
#   'Dec 21 2021'],
#  ['.............asdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdfasdf',
#   '5 ',
#   'Dec 21 2021'],
#  ["Global access made easy Formatting and email attachment's are clear and formatted to the document.",
#   '5 ',
#   'Dec 21 2021'],
#  ['Excelente hace tiempo intenté integrarla a mi cuenta de HubSpot y no funcionaba; ahora si es excelente el resultado.',
#   '5 ',
#   'Dec 20 2021'],
#  ['The HubSpot Plugin is really helpful in bringing up contact information on the spot and allowing quick access to templates and snippets. However the plugin does a terrible job with Tracking emails and is always counting my email opens as an open by my prospect and lead so my data is not accurate for email opens.',
#   '2 ',
#   'Dec 20 2021'],
#  ['Me gusta poder hacer carpetas con los diferentes emails y que se almacenen de manera correcta',
#   '5 ',
#   'Dec 20 2021'],
#  ['otimo otimo otimo otimo otimo otimo otimo otimo otimo otimo otimo otimo otimo otimo',
#   '5 ',
#   'Dec 17 2021'],
#  ['Funciona bien tienen buena relación entre HubSpot mail personal calendarios y actividades.',
#   '5 ',
#   'Dec 17 2021'],
#  ['Es una herramienta básica e indispensable en mi área laboral. Para comunicación interne y externa.',
#   '4 ',
#   'Dec 16 2021'],
#  ['Muy bien pero con la extension sirve más aun. Impactante lo de cerca que se pueden medir las campañas',
#   '5 ',
#   'Dec 16 2021'],
#  ['Great! It was extremely easy to use. Tracking was nice and the automatic attachment of the communication to the contact was great.',
#   '5 ',
#   'Dec 16 2021'],
#  ['It is working pretty well. I am excited to scale this now. I really love the automations.',
#   '4 ',
#   'Dec 15 2021'],
#  ['lots of bugs on my Macbook Pro M1 lots of bugs on my Macbook Pro M1 lots of bugs on my Macbook Pro M1',
#   '1 ',
#   'Dec 14 2021'],
#  ['All the official mails we can see and revert also with records. and save even though we forget password we can recover very easily.',
#   '5 ',
#   'Dec 14 2021'],
#  ['abcdefghijklmnopqrstuhh"uiezyirh_fui"yegfy_yug"&ehz_pgd&b"uzajfgba"yuezkfyhzbufy"g\'eahb_yufhghe',
#   '4 ',
#   'Dec 14 2021'],
#  ['Easy to install and use with HubSpot. I use to use Calendy with HubSpot. Based on easy of use with Gmail I will try using Google Calendar with HubSpot.',
#   '5 ',
#   'Dec 13 2021'],
#  ['The activity tracker is not consistent or always effective. Some contacts are reading but I get no indications they are.',
#   '2 ',
#   'Dec 13 2021'],
#  ['Permite tener varias herramientas en un solo lugar. Hace mas fácil el seguimiento de actividades',
#   '5 ',
#   'Dec 12 2021'],
#  ['This integration really needs to support mobile for email logging and tracking.',
#   '3 ',
#   'Dec 10 2021'],
#  ['O Gmail funciona muito bem com HubSpot. E podemos programar as resoluções e tarefas',
#   '5 ',
#   'Dec 9 2021'],
#  ["Gmail works well. Very well. It's the integration with HubSpot that is sometimes distracting and not helpful.",
#   '3 ',
#   'Dec 8 2021'],
#  ['Great reminder of what needs to be done and followed-up. Makes you rise above the competition who is not using such an CRM.',
#   '4 ',
#   'Dec 8 2021'],
#  ['très bien mais je cherche le SAV HubSpot pour mes questions techniques - très bien mais je cherche le SAV HubSpot pour mes questions techniques',
#   '4 ',
#   'Dec 8 2021'],
#  ['My emails are not being tracked in HubSpot even though I have tracking turned on.',
#   '2 ',
#   'Dec 7 2021'],
#  ["sync works well from all devices mobile and desktop. It's important for me to have all activities on HubSpot",
#   '5 ',
#   'Dec 7 2021'],
#  ['SuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuperSuper',
#   '5 ',
#   'Dec 7 2021'],
#  ['Gmail is fine. It does what I need from an email and a calendar. However getting the features that I value working with HS has been a challenge.',
#   '2 ',
#   'Dec 6 2021'],
#  ['Sim pois usamos o Gmail tanto para entrar em contato com novos clientes quanto para responder as pessoas que já são nossos clientes.',
#   '5 ',
#   'Dec 6 2021'],
#  ["Ca se désactive constamment. Du coup mon objectif n'est pas atteint. J'envoie des mails mais ils ne s'archivent pas",
#   '2 ',
#   'Dec 6 2021'],
#  ['Gmail is challenging when you have a long thread of emails under the same topic. There is no clear view to see what is the most updated and how threads on the email are being answered.',
#   '2 ',
#   'Dec 5 2021'],
#  ['Na minha opinião a ferramenta atende muito bem os fins propostos e o uso da ferramenta nos permite alcançar de maneira objetiva os resultados profissionais esperados.',
#   '5 ',
#   'Dec 5 2021'],
#  ['If you want to track your emails create a sophisticated CRM and leverage your Sales Pipeline I recommend this product.',
#   '5 ',
#   'Dec 3 2021'],
#  ['Easy to use great visibility in the contact and company record inside of HubSpot. A must have!',
#   '5 ',
#   'Dec 2 2021'],
#  ['Excellent for ease of use. 5 Stars across the board. I really like the 2 layer security.',
#   '5 ',
#   'Dec 2 2021'],
#  ['Excelente herramienta de apoyo diario para recibir y enviar información necesario para realizar trabajos',
#   '5 ',
#   'Dec 1 2021'],
#  ['Gmail é meu provedor padrão tem funcionado muito bem. As atualizações são bem rápidas',
#   '5 ',
#   'Dec 1 2021'],
#  ["Gmail is a great tool. I'm so glad to have it as part of my arsenal of resources!",
#   '5 ',
#   'Dec 1 2021'],
#  ['better with out HubSpot extra work to go back and forth cannot access from my phone so not want another app on my phone',
#   '1 ',
#   'Dec 1 2021'],
#  ['Its a great app but for some reason its broken for me. Does not integrate with Gmail well',
#   '3 ',
#   'Dec 1 2021'],
#  ['Me gusta que desde la aplicación se pueda crear y registrar el correo y se pueda ver el historial desde aqí al igual que se puede visualizar la aparturas clics de mis correos y los documentos que le envío',
#   '5 ',
#   'Nov 30 2021'],
#  ["Using HubSpot to track all your sales & customer emails is fantastic. Records get updated and you have a great information about your communications. The one major major issue is that you have to be really careful about tracking emails because you can end up with a pile of contacts in HubSpot that shouldn't be there. And worse you can end up with legal investor and other emails & documentation inside HubSpot for others to see. HubSpot needs to make it easier to filter out contacts that you don't want to track. It is possible to do this it just isn't easy.",
#   '2 ',
#   'Nov 29 2021'],
#  ['funciona perecto facilita mucho mi gestión diaria en el proceso de ventas .',
#   '5 ',
#   'Nov 29 2021'],
#  ['Easy to use and set up - works well. Really please with how straightforward is was to set up with Gmail (which we used already) can now easily track all communication associated with each deal',
#   '5 ',
#   'Nov 29 2021'],
#  ["working very well for us so far. We are only 2 weeks in though so there's still time :P",
#   '5 ',
#   'Nov 29 2021'],
#  ["It's working well and I will continue to use it more often with my prospects.",
#   '4 ',
#   'Nov 26 2021'],
#  ['That is none of your concern.....................................................',
#   '3 ',
#   'Nov 26 2021'],
#  ['ça marche super bien je recommande ça a changé ma vie bien entendu hahahahah',
#   '5 ',
#   'Nov 24 2021'],
#  ['Gmail est un outil facile à prendre en main et facile gérable sur plusieurs supports que ce soit le téléphone ou le PC - il a une grande accessibilité et a en plus un belle capacité de stockage de données ce qui facilite les échanges de data sans perte de qualité.',
#   '3 ',
#   'Nov 24 2021'],
#  ['this is major for seeing how the email is being received and responded to from the sender',
#   '3 ',
#   'Nov 24 2021'],
#  ["It is working well - I need to be better at using it's functionality and features.",
#   '4 ',
#   'Nov 24 2021'],
#  ['Good. However we need a better way to total the number of emails that are made on a daily weekly etc basis.',
#   '4 ',
#   'Nov 23 2021'],
#  ['L\'extension Gmail HubSpot permet de suivre et d\'enregistrer les échanges prospects et clients facilement. La fonction "ne jamais enregistrer" permet de conserver la maîtrise sur sa création de nouveaux contacts. De quoi garder son CRM propre.',
#   '5 ',
#   'Nov 23 2021'],
#  ['Extensão funcionando após instalação ajuda no processo de vendas e nosso time comercial.',
#   '5 ',
#   'Nov 22 2021'],
#  ['Was and is fairly easy to learn both tools; and to utilize different aspects of both to coordinate my daily tasks.',
#   '4 ',
#   'Nov 22 2021'],
#  ['Excelente calidad facilidad manejo sencillo alta capacidad de integración',
#   '5 ',
#   'Nov 22 2021'],
#  ['I like that I can access the CRM and assets directly from Gmail (Snippets Templates etc).',
#   '5 ',
#   'Nov 22 2021'],
#  ['Gmail me es muy funcional y práctico pero la vinculación con HubSpot no es tan sencilla de aprender sobre todo cuando no se desea que todos los correos (contactos) tengan esta vinculación',
#   '3 ',
#   'Nov 20 2021'],
#  ['It was not working. But your team put up with my fears of communications and got the job done.',
#   '5 ',
#   'Nov 19 2021'],
#  ['Funciona muy bien y permite un manejo de la informacion muy dianamico por lo tanto excelente aplicacion',
#   '5 ',
#   'Nov 19 2021'],
#  ['The integration failed to capture all emails being sent. Not able to track down why.',
#   '2 ',
#   'Nov 18 2021'],
#  ['Es fácil de manejar y muy intuitivo. Me ayuda a controlar mejor el seguimiento de mis correos y también a redactarlos de mejor forma.',
#   '5 ',
#   'Nov 18 2021'],
#  ['using Gmail I can connect all y others email accounts and and a only one view',
#   '5 ',
#   'Nov 18 2021'],
#  ["Gmail offre à ses utilisateur une facilité d'utilisation avec une multitude de fonctionnalités pratiques et gratuit.",
#   '2 ',
#   'Nov 17 2021'],
#  ["It's great and it is easy to use I am able to easily see whom opened my email and when.",
#   '4 ',
#   'Nov 17 2021'],
#  ['I have multiple email address and I am using Spark to combine it all. It also has calendar extension and now I have to use also chrome and gmail on the side.',
#   '1 ',
#   'Nov 17 2021'],
#  ['Gmail is great but for some reason even when I open my inbox I get alerts showing my recipient opened the mail.',
#   '3 ',
#   'Nov 17 2021'],
#  ['Tudo funciona mt bem porém não consigo fazer de forma fácil com que um e-mail que eu recebi por fora do HubSpot volte a ter sua cadência por aqui. Por exemplo se eu mando uma mensagem pelo Hub e copio dois destinatários porém um deles clicar em "responder só para mim"',
#   '5 ',
#   'Nov 16 2021'],
#  ['I enjoy the functionality. I used calendly for years and it never worked well with other programs.',
#   '4 ',
#   'Nov 16 2021'],
#  ['Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good Good and Good.',
#   '4 ',
#   'Nov 16 2021'],
#  ["When creating a Meeting on HubSpot it not only added it to my Google Calendar but it shared it with my client's including all of my notes (that I thought would be private). To avoid this I just removed Google from HubSpot so that booking meetings on HubSpot does not email my clients. I will just manually add meetings to my Google Calendar.",
#   '1 ',
#   'Nov 16 2021'],
#  ['I have multiple Gmail addresses that fully integrate with my HubSpot account. Making it super easy to associated contacts with the various emails that get sent.',
#   '5 ',
#   'Nov 16 2021'],
#  ["HubSpot's Gmail plugin is an effective way to send and track emails to customers prospects team members and vendors. Highly recommend it.",
#   '5 ',
#   'Nov 16 2021'],
#  ['funciona bien  es fácil de usar e ingresar la es amigable con mi conexiones',
#   '5 ',
#   'Nov 16 2021'],
#  ['It is great tool to communicate with leads. Very easy to use and has lot of other tools which helps the sales people. For example Google search calendar Google meet.',
#   '5 ',
#   'Nov 16 2021'],
#  ['We are on Google Workspace so Gmail is the logical solution. It works great for us. It would be great to access my personal Gmail emails in HubSpot too like in PipeDrive. It would make answering non-shared-inbox emails so much easier in HubSpot.',
#   '4 ',
#   'Nov 16 2021'],
#  ['Working well for me and the business regarding the e-mail services will recommend to others',
#   '5 ',
#   'Nov 16 2021'],
#  ["HubSpot's integration with Gmail just doesn't stack up against many (most?) of the other sales engagement and automation platforms.",
#   '2 ',
#   'Nov 15 2021'],
#  ["joe@me.net wants some insurance. I add him to HubSpot and can track my calls and emails to Joe. I will get other emails from underwriting@insuranceco.com and applicationreceived@insuranceco.com some of which I will want to attach to Joe or (Joes 100k policy Deal) (others of course from those same emails need to be attached to mary@me.net or susy@me.net) this requested feature has had good feedback in the HubSpot community boards but has not been implemented. Other than that you'll be hooked if you dip you feet in and use the product. It will help you track all those things spead between your calendar your email your sms and your call log all those things that are slipping between the cracks and losing you deals.",
#   '3 ',
#   'Nov 15 2021'],
#  ['Excelente parceria entre as empresas. Só temos a criar mais sinergia. Estamos trilhando uma jornada de inovação e tecnologia',
#   '4 ',
#   'Nov 13 2021'],
#  ['Gmail really works excellent on my business transactions. So precise on time and very helpful.',
#   '5 ',
#   'Nov 13 2021'],
#  ['Gmail is a very efficient instrument for our company. The integration with HubSpot helps managing better the relations with our clients and stay on top of everything.',
#   '5 ',
#   'Nov 12 2021'],
#  ['Die Erweiterung setzt sich "oben auf GMail" und zerstört die Nutzererfahrung an vielen Stellen. Insbesondere indem sie den Fokus klaut. Dadurch löst man aus versehen shortcuts aus und löscht mails. Sehr problematisch.',
#   '2 ',
#   'Nov 11 2021'],
#  ["Overall it has been good. Good integration with other software I am using. HubSpot experience was horrible though. It's the worst a CRM can offer.",
#   '1 ',
#   'Nov 11 2021'],
#  ['email tracking helps provide insight and clarity into past customer/prospect interactions. snippets and templates save loads of time. meeting links too! all of these features are intuitive and easy to access within Gmail.',
#   '5 ',
#   'Nov 10 2021'],
#  ['Toda nossa comunicação fica integrada a plataforma deixando o histórico das tratativas em nosso contato e/ou negócio.',
#   '5 ',
#   'Nov 10 2021'],
#  ['Es muy intuitivo y eso me gusta bastante es muy fácil de usar y no he tenido problema alguno en su uso.',
#   '4 ',
#   'Nov 10 2021'],
#  ['MUY BIEN YA QUE DA LA FACILIDAD DE COMUNICACIÓN Y ADJUNTAR FORMATOS SOLICITADOS',
#   '4 ',
#   'Nov 10 2021'],
#  ['Correcto. El tener integrado el aviso de tareas en ambas aplicaciones me hace avanzar en el día a dia.',
#   '5 ',
#   'Nov 10 2021'],
#  ["It is frustrating to me when I get error messages but I can't see what the error is. There is one error message with 5 listed reasons of why you might have received the error.",
#   '2 ',
#   'Nov 9 2021'],
#  ['Funciona muy bien para poder comunicar los correos que se envian en el uso de los recordatorios por ejemplo.',
#   '4 ',
#   'Nov 9 2021'],
#  ['HubSpot plug in shows up on gmail but the emails are not logged/synced in HubSpot.',
#   '1 ',
#   'Nov 9 2021'],
#  ['Overall is working pretty well the only thing that I find slightly troublesome is the fact that it does not remain pinged nor does it maintain the window opened for calendars for instance.',
#   '4 ',
#   'Nov 9 2021'],
#  ['Muy bien tenemos la facilidad de comunicarnos con los clientes y con nuestro equipo de una forma rápida',
#   '5 ',
#   'Nov 9 2021'],
#  ['Gmail es un aliado más que una herramienta la gran mayoría de empresas con las cuales interactuamos lo tienen y eso facilita no solo videollamadas sino también el trabajo colaborativo.',
#   '5 ',
#   'Nov 8 2021'],
#  ['If I had a choice I would dump HubSpot and get Salesforce. HubSpot has yet to be helpful to me without lots of headaches.',
#   '1 ',
#   'Nov 8 2021'],
#  ['It works well. We used some shitty program called Goldmine before (think windows outlook 2005)...',
#   '4 ',
#   'Nov 8 2021'],
#  ['Fehlerfrei manchmal gibt es Aussetzer aber das ist normal kein Server hat 100% Uptime',
#   '3 ',
#   'Nov 8 2021'],
#  ['This is a "must have" for me. All e-mail are linked to the company and the contact.',
#   '5 ',
#   'Nov 7 2021'],
#  ['Muy familiarizado con gmail y con laplataforma google suite empresarial y personal',
#   '5 ',
#   'Nov 6 2021'],
#  ['Agilidad en los procesos y facilidad de uso en los diferentes apps que tiene gmail.',
#   '5 ',
#   'Nov 5 2021'],
#  ['Gmail is mission critical for our company and my personal work life. I use it for many applications in all areas of my life.',
#   '5 ',
#   'Nov 5 2021'],
#  ['Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien Bien',
#   '4 ',
#   'Nov 4 2021'],
#  ['The overall integration works well but I suggest to integrate the tasks too',
#   '4 ',
#   'Nov 3 2021'],
#  ['Comes Easy to use and has a lot of features. Using it to track the conversation and email to lead generation. Must have for everyone!',
#   '5 ',
#   'Nov 3 2021'],
#  ['Todo el tiempo se desvincula de mi gmail. Y debo logiarme nuevamente...................',
#   '2 ',
#   'Nov 3 2021'],
#  ["C'est notre boite pro mais elle n'a pas l'air parametrable pour l'instant.",
#   '1 ',
#   'Nov 3 2021'],
#  ['The integration between Gmail and HubSpot is working extremely well thank you!',
#   '5 ',
#   'Nov 3 2021'],
#  ["It's okay but should have more features and be quicker to use. I'd like to see whether an email was opened without opening it myself.",
#   '2 ',
#   'Nov 3 2021'],
#  ['Funciona genial es una herramienta útil y muy eficaz de comunicación para los usuarios',
#   '5 ',
#   'Nov 2 2021'],
#  ['good no time to write in details................................................',
#   '5 ',
#   'Nov 2 2021'],
#  ['Nice integration overall. I like having my emails at my fingertips in HubSpot.',
#   '4 ',
#   'Nov 2 2021'],
#  ['Es una plataforma mucho más amigable y facil de usar. Facil de configurar y personalizar.',
#   '5 ',
#   'Nov 2 2021'],
#  ['HubSpot is probably the best help desk service available in the market right now and their support is awesome! The navigation is simple and easy to use. Overall a much better experience than Zendesk.',
#   '5 ',
#   'Nov 2 2021'],
#  ['Gmail is use for communication service complaints services management Lots of mail are for advertising purpose after Unsubsribe the mails are frequently comes with another titles.',
#   '2 ',
#   'Nov 1 2021'],
#  ['mi empresa asido muy funcional y mas que a hora contamos con su nueva herramienta de trabajo',
#   '5 ',
#   'Oct 29 2021'],
#  ["Gmail itself is going well -- it's not really a personal choice more that we have subscribed to Google Workspace as a business and that comes with gmail.",
#   '5 ',
#   'Oct 28 2021'],
#  ['Sim o Gmail atende a minha a necessidade por enquanto não tenho um volume de demanda.',
#   '5 ',
#   'Oct 28 2021'],
#  ['Ótima ágil e eficiente. Me ajuda no dia a dia na comunicação com novos prospects.',
#   '5 ',
#   'Oct 28 2021'],
#  ['Works well if you want all mail to be controlled by HubSpot but falls down when only some mail is to be managed - even if no mail is to be managed.',
#   '2 ',
#   'Oct 28 2021'],
#  ['Con la vinculación de Gmail y HubSpot el seguimiento con los clientes se queda guardado no importa si se contesta desde Gmail o HubSpot el seguimiento se queda guardado. Me encanta que desde Gmail esta vinculada la empresa y así puedo acceder rápidamente a la empresa en HS',
#   '5 ',
#   'Oct 28 2021'],
#  ['Browser-based email is the f-ing worst interface. Bring back command line!',
#   '1 ',
#   'Oct 27 2021'],
#  ['Sim. Com o uso do Gmail traz muita facilidade pois conseguimos ter um acesso quase único junto ao HubSpot.',
#   '5 ',
#   'Oct 27 2021'],
#  ['Estoy acostumbrada porque es mi cuenta personal adicional a que tienes todo el ecosistema de calendario reuniones y contactos. Esta integración de plataformas mejora la agilidad en las actividades diarias.',
#   '5 ',
#   'Oct 27 2021'],
#  ['Espectacular la experiencia con HubSpot. Nos ha permitido automatizar nuestro trabajo. Espero pronto unir mas herramientas del sistema.',
#   '5 ',
#   'Oct 26 2021'],
#  ["I would say is bad because I'm missing tickets from my customers. Emails do not reach HubSpot!",
#   '2 ',
#   'Oct 26 2021'],
#  ['Gmail in Google Workspace works pretty well and I love it. Itegration with HubSpot is easy set in HubSpont Email settings',
#   '5 ',
#   'Oct 26 2021'],
#  ['This is a must-use integration for HubSpot & Gmail clients. It is one of my main sales tools and a true g-d send.',
#   '5 ',
#   'Oct 25 2021'],
#  ['I love to know what the team is up to and to be able to arrange meeting and keep record of all meetings in HubSpot.',
#   '5 ',
#   'Oct 25 2021'],
#  ['It is simple to use. It is direct. easy to manage and setup in a way that works for our business.',
#   '4 ',
#   'Oct 25 2021'],
#  ['Funktioniert sehr stabil. Ich bin zufrieden. Lediglich die Erstellung von Aufgaben in Gmail direkt könnte noch etwas flexibler gestaltet sein.',
#   '5 ',
#   'Oct 25 2021'],
#  ['me parace todo lo que por el momento se haces va bastante bien. Para poder dar una valoración más concreta debo seguir aprendiendo a usar todas las funcionalidades posibles. En base a esto debep decir que los correos con tips de com usar tanto HubSpot como gmail son excelentes.',
#   '4 ',
#   'Oct 25 2021'],
#  ['Fair nothing special hard to get answers to questions help and support weak',
#   '3 ',
#   'Oct 22 2021'],
#  ['Perfeitamente não tenho o que reclamar do gmail conectado ao HubSpot. Até o momento tem me atendido demais',
#   '5 ',
#   'Oct 22 2021'],
#  ['Funciona muy bien es una excelente herramienta la cual es compatible con varias herramientas',
#   '5 ',
#   'Oct 22 2021'],
#  ['Ojalá podiera uno seleccionar qué correos son para enrutar y cuáles no. Quisiera saber también más de HubSpot ya que solo lo he usado una vez.',
#   '3 ',
#   'Oct 21 2021'],
#  ['Gmail is ok. HubSpot still trying to learn the ins and outs of it and how ity works with my Ion Capital Solutions business',
#   '3 ',
#   'Oct 21 2021'],
#  ['Gmail es una herramienta fácil de utilizar para gestión de correos. El agregar utilidades de monitoreo de comunicaciones apoya la gestión de la comunicación y diseño de estrategias a partir de la información.',
#   '4 ',
#   'Oct 21 2021'],
#  ['Buena  pero mejorable. Hay muchas funciones que no son faciles de ajustar  igual creoque la ayuda existe y no la he buscado lo suficiente',
#   '4 ',
#   'Oct 21 2021'],
#  ['No information to fix HubSpot - Gmail fix limited only to some overarching general guides. Documentation is poor. Driving our organisation crazy.',
#   '1 ',
#   'Oct 21 2021'],
#  ['0. horrible. affects negatively tremendously. no support whatsoever!!I i have been trying to get help by all means but nobody answer me. please help me asap. thanks!',
#   '1 ',
#   'Oct 20 2021'],
#  ['All working fine for my needs. Simple to use and understand when training others to use.',
#   '5 ',
#   'Oct 20 2021'],
#  ['Sim está funcionando normalmente. Muito bom esse aplicativo.. Melhor experiência',
#   '5 ',
#   'Oct 20 2021'],
#  ['This review is specifically for Gmail integration with SalesHub and not HubSpot overall. My work is done primarily within Gmail and you are not auto-alerted within Gmail in a user-friendly way. You have "open" SalesHub to see a list of relevant activities/opens/clicks etc.. instead of being able to see them in Gmail. Also the reporting features are very limited and you cannot "batch enroll" a list of leads/contacts. SalesHub caps at 50 contacts -- not very efficient... Compared to MixMax and SalesLoft -- SalesHub significantly falls short of being a sales-centric tool.',
#   '1 ',
#   'Oct 20 2021'],
#  ['Algunas funciones no se encuentran habilitadas. El espacio de la firma electronica es mayor al del cuerpo del correo',
#   '4 ',
#   'Oct 19 2021'],
#  ['Gmail and G Suite work very well for us on the whole. Only issue is deeply nested messages are not easy to work with',
#   '4 ',
#   'Oct 19 2021'],
#  ['Task reminders notifications through Gmail is a real added value compare to other CRMs (eg SalesForce)',
#   '5 ',
#   'Oct 19 2021'],
#  ['Fine................................................................................',
#   '3 ',
#   'Oct 18 2021'],
#  ["In general HubSpot is a helpful tool for sales. However the Gmail integration could be more user-friendly especially (at least in my case) tagging email threads to specific projects. I'm having trouble locating the correct project. An auto-fill search feature that works is all I need. I have multiple projects per vendor/contact so that may lead to confusion.",
#   '3 ',
#   'Oct 18 2021'],
#  ['Can track notes and e-mails and any communication that was had in one spot. Makes it easier to follow up on calls as well as set up tasks...weekly',
#   '4 ',
#   'Oct 18 2021'],
#  ['excelente herramienta solución simple e intuitiva favorece el cierre de ventas',
#   '5 ',
#   'Oct 18 2021'],
#  ['Me funciona bien me da facilidades en el seguimiento de los correos dentro de la empresa.',
#   '5 ',
#   'Oct 18 2021'],
#  ['Muy bien facilita el trabajo en gran medida y ofrece una linea de conexión con los clientes. Está muy bien integrado y quizas falta poder sincronizar la firma en lugar de ponerla en cada sitio por separado',
#   '5 ',
#   'Oct 18 2021'],
#  ['Funciona bien y la incidencia ha sido muy positiva como complemento al resto de herramientas.',
#   '4 ',
#   'Oct 18 2021'],
#  ["I have a lot of ideas on how this could improve. I use it every day. It's just not everything I want it to be. It's close but its just not quite there.",
#   '3 ',
#   'Oct 17 2021'],
#  ['I have a lot of meetings and having them pop up and easy to access through slack saves a lot of clicking.',
#   '5 ',
#   'Oct 16 2021'],
#  ['Bien me está ordenando. Falta un poco de claridad en la asistencia técnica',
#   '4 ',
#   'Oct 15 2021'],
#  ['Gmail is brilliant. I love the tools and apps I can add to it to creat my workspace.',
#   '5 ',
#   'Oct 14 2021'],
#  ["It's been difficult to go from SFDC to HubSpot to be honest. the template editing is not great neither as it does not refresh",
#   '2 ',
#   'Oct 14 2021'],
#  ['The perfect application! EVERRYTHING YOU NEED IS AT THE TIP OF YOUR HANDS! I LOVE HOW IT CREATES TEMPLATES AFTER IT NOTICES YOU COPYING AND PASTING! IT IS A PHENOMENAL APP!',
#   '5 ',
#   'Oct 14 2021'],
#  ['Gmail is a bit delayed in syncing with HubSpot ( when a lead is assigned). which might be critical when a direct demo is associated to one contact.',
#   '3 ',
#   'Oct 14 2021'],
#  ['Creo que el funcionamiento es bueno y el hecho de que esté ligado a HubSpot es genial pero creo que le añadiría funciones como por ejemplo el poder incluir "tarea" en el email o poder incluir las plantillas que tenemos en HubSpot desde gmail. Estas 2 funciones estaría bien tenerlas diponibles igual que está disponible la casilla de "seguimiento".',
#   '4 ',
#   'Oct 14 2021'],
#  ['Great to be able to be in HubSpot or Gmail and move freely between the two',
#   '4 ',
#   'Oct 13 2021'],
#  ['We will never look back We are very happy with the choice we made as a business to proceed with this service.',
#   '5 ',
#   'Oct 13 2021'],
#  ['Funciona bien y me permite crecer en mi negocio.Porque con las nuevas funcionalidades se logra mas productividad.',
#   '5 ',
#   'Oct 13 2021'],
#  ['Gmail works fine. HubSpot messages end up not reaching the target audience. Why do I need 75 characters for feedback? It is terrible',
#   '1 ',
#   'Oct 13 2021'],
#  ['great CRM very extensive in capability... I am only an employee as a user and this CRM is very good at helping to guide my outbound calls and prospecting each day. Additionally- it seems great for reports that my employer needs to monitor as well.',
#   '5 ',
#   'Oct 12 2021'],
#  ['Personalmente prefiero trabajar con otro software que permita trabajar con carpetas (folders). Con el gmail trabajar y archivar con carpetas es muy incómodo porque es un árbol que se despliega con el paso del mouse en una ventana muy pequeña para mi forma de trabajo',
#   '2 ',
#   'Oct 12 2021'],
#  ['tres simple d utilisation', '2 ', 'Oct 12 2021'],
#  ['Fine with Google Chrome G-Mail and HubSpot to connect. I would like to know how to find Schedule Task to HubSpot.',
#   '5 ',
#   'Oct 11 2021'],
#  ['Improved my sales process completely by integrating my HubSpot CRM into Gmail.',
#   '5 ',
#   'Oct 11 2021'],
#  ['Es practico de usar me sirven mucho las plantillas para enviar mensajes a los clientes',
#   '5 ',
#   'Oct 10 2021'],
#  ['IT is helping me receive more connections. I have been able to book more meetings using gmail with HubSpot than my last CRM',
#   '4 ',
#   'Oct 8 2021'],
#  ['Does not work on Mozilla Firefox. I use Firefox through choice and this contractual stitch-up means that I am having to use two different browsers at once.',
#   '2 ',
#   'Oct 8 2021'],
#  ['we do not have gmail we use microsoft', '5 ', 'Oct 7 2021'],
#  ["Gmail and Google Docs are a daily fundamental for our small business. Add to those the ease of use of our Youtube channel and it's a huge win for us.",
#   '5 ',
#   'Oct 7 2021'],
#  ['Working really well! The automated integration makes it easy to log Emails and conversations.',
#   '5 ',
#   'Oct 7 2021'],
#  ["I'm having problems with saving the emails and attachments into the deals when I'm receiving them",
#   '3 ',
#   'Oct 7 2021'],
#  ["The Gmail integration works very well. I set it up years ago and often forget it's not just a part of Gmail!",
#   '4 ',
#   'Oct 6 2021'],
#  ['SE TRABAJA MUY BIEN CON LA PLATAFORMA Y GMAIL LA INTEGRACION ES MUY BUENA Y SENCILLA DE USAR',
#   '5 ',
#   'Oct 6 2021'],
#  ['WISELY DESIGNED VERY SENSITIVE TO GMAILVERY RICH IN DATA VERY VERY VERY GOOD',
#   '5 ',
#   'Oct 6 2021'],
#  ['Reduce time and effort on email communication data exchange tracking customer actions building a customer profile',
#   '5 ',
#   'Oct 6 2021'],
#  ['Bien. Es una buena integración me encanta enviar un mail y verlo todo en HubSpot luego',
#   '4 ',
#   'Oct 5 2021'],
#  ['buena herramienta buena herramienta buena herramienta buena herramienta buena herramienta buena herramienta.',
#   '4 ',
#   'Oct 5 2021'],
#  ['100 % perfect wont change as its important for so many features see above',
#   '5 ',
#   'Oct 4 2021'],
#  ['Random. Los contactos y las empresas no son generados sistemáticamente y eso genera desconfianza. Puede que deje de usar HubSpot.',
#   '2 ',
#   'Oct 4 2021'],
#  ['Gmail works well for us and meets all expectations. Ease of use connection to other applications pricing.',
#   '5 ',
#   'Oct 2 2021'],
#  ['Gmail is fine. HubSpot is fine. But the two don’t work together well from a phone or IPad. I have to put in a bcc or forward code to get HubSpot to log my emails sent from gmail. Also why can’t I attach a file to an email sent from HubSpot?',
#   '2 ',
#   'Oct 1 2021'],
#  ['Muy bien me ha funcionado acorde a mis necesidades tiene una buena interface.',
#   '5 ',
#   'Oct 1 2021'],
#  ['Gmail has always been great. Have never had a problem with Gmail or google products.',
#   '2 ',
#   'Oct 1 2021'],
#  ['I get multiple notifications on my phone that someone opened my emails but in many cases I know I am getting the notifications late or incorrectly. I know this because for awhile it was sending me notifications that my boyfriend was opening a email repeatedly but he said he was not. And from clients I will get like 10 notifications that they opened an email and I doubt that they opened it 10 times. And I wish that when I sent an email directly from my gmail HubSpot would let me know if someone clicked any of the links. That would be helpful.',
#   '3 ',
#   'Oct 1 2021'],
#  ['5 stars hands down. The notification and interface are stellar and easy to use and figure out.',
#   '5 ',
#   'Sep 30 2021'],
#  ['Funciona bastante bien puedo encontrar todo lo necesario con facilidad de modo a responder a la demanda de los clientes',
#   '5 ',
#   'Sep 30 2021'],
#  ['I love it the time it saves me on logging communications and emails is amazing...',
#   '5 ',
#   'Sep 30 2021'],
#  ['Not satisfied at all. Frustrated with functionality. Stopped my outreaching altogether',
#   '1 ',
#   'Sep 29 2021'],
#  ["Grateful to have this integration but much could be improved. Would like to see more automatic triggering of syncing new email chains with contacts in HubSpot (not having to remember to BCC a random email address). I'd also like to see more control over which new contacts are created in HubSpot (i.e I don't want emails to non-leads to end up in HubSpot).",
#   '2 ',
#   'Sep 29 2021'],
#  ['O gmail está funcionando muito bem pra mim tanto com agendas quanto com o calendário. Com essa integração eu diminuo o meu tempo de manuseio em tarefas repetitivas e tenho menos perdas de oportunidades em agendamentos com a facilidade do link de reuniões - e o melhor sem custo para a minha empresa que ainda é pequena e precisa desse dinheiro em outros lugares.',
#   '5 ',
#   'Sep 29 2021'],
#  ['Funciona perfectamente y la integración es muy buena . Muy fácil de usar  intuitiva. Me gusta que además notifica cuando abren un correo',
#   '5 ',
#   'Sep 29 2021'],
#  ['It is working great. It would be great if there was integration with the native mac mail system as this is what I was using but it has not been too difficult to run gmail for biofab through a web browser. it is definitely worth doing that to have the HS plug in there.',
#   '5 ',
#   'Sep 28 2021'],
#  ['I love the plugin. It is really the key feature of HubSpot for me. The min 7',
#   '4 ',
#   'Sep 28 2021'],
#  ['ITS ME NOW I havent taken the time to truly give it a shot .. This system takes time that takes me away from selling',
#   '3 ',
#   'Sep 27 2021'],
#  ['não consigo integrar o email por isso não consigo beneficiar da integração que existe entre as duas marcas',
#   '1 ',
#   'Sep 27 2021'],
#  ['Funciona bien el seguimiento y el registro de los contactos. Sin embargo de un tiempo para acá cada vez que envío un correo desde Gmail la extensión de HubSpot hace que se copie mi correo (Del cual estoy enviando) en cco y llega como copia a la bandeja de entrada lo cual es sumamente desesperante. Intenté desintalar la extención y sin ella funciona normal lo que quiere decir que es un problema de la extención de HubSpot. Intente ver en el blog de usuarios y hablar con un asesor pero no consigo la solución.... Muy triste',
#   '2 ',
#   'Sep 27 2021'],
#  ['Duas grandes ferramentas que não fico sem em meu negócio. Muito bom e útil os recursos disponíveis.',
#   '5 ',
#   'Sep 27 2021'],
#  ['Great alternative to connecting your inbox to HubSpot when you want to pick and choose what gets recorded.',
#   '5 ',
#   'Sep 24 2021'],
#  ['GMAIL funciona bem sim. o tracking de mensagens de email relacionados com tickets HubSpot e negocios abertos não funciona bem',
#   '3 ',
#   'Sep 24 2021'],
#  ['WOW so easy to use. You can easily add people to sequences use snippets and I love the open receipts that I get. If you use google just get the integration.',
#   '5 ',
#   'Sep 24 2021'],
#  ['i can access work anywhere instead of installing outlook in my personal devices',
#   '5 ',
#   'Sep 24 2021'],
#  ['Using HubSpot with Gmail is a deterrent to our business efficiency. It would behoove HubSpot to seek closer integration with other email platforms to see greater adoption from teams that must prioritize task allocation and operations through integrated communications over marketing and sales.',
#   '2 ',
#   'Sep 23 2021'],
#  ["Default option to send to HubSpot must be OFF. Instead it's by default ON thus all my personal emails also sometimes ends up in HubSpot.",
#   '1 ',
#   'Sep 23 2021'],
#  ["It's really nice. It allows me to schedule emails / sync all communication and allows me to easily change properties directly from the right side panel",
#   '5 ',
#   'Sep 22 2021'],
#  ['Efficient Great Easy to use Able to organize everything Wish Google groups was this way',
#   '5 ',
#   'Sep 22 2021'],
#  ['This combination is perfect it helps me understand what is going on with the email I sent after it left my side. :)',
#   '5 ',
#   'Sep 22 2021'],
#  ['It integrates well and its a lot of improvement comparing just to couple years back esspecialy working with different accounts simultaneously',
#   '5 ',
#   'Sep 22 2021'],
#  ['una información mas eficiente xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx',
#   '5 ',
#   'Sep 22 2021'],
#  ['Gmail is not only mail program. It whole communication centre which helps keep all in one place.',
#   '4 ',
#   'Sep 21 2021'],
#  ['Mala hace cosas que no quiero que haga y no es claro como deje de hacer lo que uno no quiere',
#   '2 ',
#   'Sep 21 2021'],
#  ["It ended up creating an entire company record for the 3rd party that was not necessary and I can't cleanly merge it in with my original client record",
#   '2 ',
#   'Sep 21 2021'],
#  ['.......................................................................................',
#   '5 ',
#   'Sep 21 2021'],
#  ["It's great. Love that any communication sent is tracked on a contacts record on HubSpot",
#   '5 ',
#   'Sep 21 2021'],
#  ['xgfjfgjfghfhgfghfghfghfghfghfghdfserwersdshyjukytyuytuyfghghffgdfgddfgdsdgsdgsdfsdfsdfsdfh',
#   '5 ',
#   'Sep 20 2021'],
#  ['Emails that were recorded in early September are now missing. Can someone please find them?',
#   '1 ',
#   'Sep 20 2021'],
#  ['Gmail works great HubSpot in this instance is garbage literally it has me worrying about who received a personal email from me that would be a contact in HubSpot now up to 13 recipients when I only sent it to 4 people wtf!!!',
#   '1 ',
#   'Sep 20 2021'],
#  ['It great so far! I am getting used to it and the integration with HubSpot is really something which added more features.',
#   '4 ',
#   'Sep 20 2021'],
#  ['Its good Its goodIts goodIts goodIts goodIts goodIts goodIts goodIts goodIts goodIts goodIts good',
#   '5 ',
#   'Sep 17 2021'],
#  ['NA - There was NO call from HubSpot at the arranged time....................',
#   '1 ',
#   'Sep 17 2021'],
#  ["Sometimes when I answer to an email on Gmail it doesn't sync directly with HubSpot and I have to log it manually.",
#   '3 ',
#   'Sep 16 2021'],
#  ["It has been good but the HubSpot attachement creates contacts from a person's email domain. should be an option to select an account to attach.",
#   '4 ',
#   'Sep 16 2021'],
#  ['Es la herramienta de trabajo que utilizamos en la empresa de trabajo para cotizar y estar en contacto con los clientes',
#   '1 ',
#   'Sep 15 2021'],
#  ['Very nice! I am very please with the HubSpot and Gmail integration easy to use and lots of functionality. Reliable too!',
#   '5 ',
#   'Sep 15 2021'],
#  ['Es el mail por preferencia pero no tiene ninguna diferenciación de otras . Es simplemente la que utilizamos.',
#   '3 ',
#   'Sep 14 2021'],
#  ['me funciona a la perfección no me gusta que no tenga como agrupar por carpetas mis correos y que lleguen directamente a esa carpeta los correos seleccionados eso me daría mas orden a la hora de ver mi correo.',
#   '5 ',
#   'Sep 14 2021'],
#  ['positivamente para cumplir con los requerimientos y las metas establecidas',
#   '5 ',
#   'Sep 14 2021'],
#  ['It makes it easier to do my job on a daily basis. I find it helpful and easy to use.',
#   '4 ',
#   'Sep 13 2021'],
#  ['Helps with tracking and organization. Ease of searching and finding emails through keywords.',
#   '4 ',
#   'Sep 13 2021'],
#  ['En general funciona bien y me da cobertura a la mayoría de las necesidades que tengo en comunicación.',
#   '5 ',
#   'Sep 13 2021'],
#  ["The hub spot GMail integration didn't work for me it said I don't have an email account associated with",
#   '1 ',
#   'Sep 12 2021'],
#  ['Reply Emails Not Tracked. Wished They Were. When sending emails thru HubSpot the original email seems to contain tracking info but subsequent replies to the same thread dont seem to auto-integrate and need to be logged manually. not sure if this is the case or if we are just using the features incorrectly.',
#   '2 ',
#   'Sep 10 2021'],
#  ['Tricky to manage Tickets by using emails. easy to track emails by using HubSpot plugin',
#   '3 ',
#   'Sep 10 2021'],
#  ['This is one of the better Gmail integrations out there. All emails can be tagged if you want to track them if yes the contact gets created in HubSpot existing contacts the mail is linked as a communication history. You can tag the email to be linked to contact deal and/or organization. Amazing tool to keep track of communication history.',
#   '5 ',
#   'Sep 10 2021'],
#  ["I don't know how I would function without this integration. I've used both gmail and outlook and I would say that the outlook plugin is more useful mainly because I'm able to easily schedule new tasks while in gmail. There is some room for improvement however.",
#   '4 ',
#   'Sep 9 2021'],
#  ['Did not integrate Gmail to hubs pot kdkdkdkdkdkkdkdkdkdkdkkdkdkdkdkkdkdkkdkdkdk',
#   '1 ',
#   'Sep 9 2021'],
#  ["However for me personally at least 90% of the emails I'm sending out aren't in interest for the HubSpot plugin. I'm missing a feature where every time I write an email HubSpot isn't automatically set to track and log every email but instead I would have to add this when relevant.",
#   '2 ',
#   'Sep 9 2021'],
#  ["It often is a company process to ensure everyone is making their correspondence visible to the rest of the company. In previous years most CRMs would allow this by bcc'ing a set address. This wasn't ideal  people forget these rules so the gmail integration makes this foolproof",
#   '5 ',
#   'Sep 7 2021'],
#  ['Did not work at all. Could Not Properly Integrate with the companies contact list.',
#   '1 ',
#   'Sep 7 2021'],
#  ["Gmail is the best emailing service and it's FREE! Couldn't be happier with the integration of Gmail.",
#   '5 ',
#   'Sep 7 2021'],
#  ['It works great BUT you should use the GMail extension (which I had to figure out myself) or EVERYTHING from Gmail will end up in HubSpot.',
#   '4 ',
#   'Sep 7 2021'],
#  ['I installed HubSpot and I use it along side my Gmail it seems to work very well.',
#   '5 ',
#   'Sep 7 2021'],
#  ['Está a funcionar muito bem. Estou muito satisfeita com o Gmail e também com o HubSpot. Duas áreas que se complementam na perfeição.',
#   '5 ',
#   'Sep 6 2021'],
#  ['Gmail funciona perfectamente rápido y con seguridad no tengo problema en ese sentido',
#   '1 ',
#   'Sep 3 2021'],
#  ['The Gmail/HubSpot integration is super helpful - use templates tracking follow-up task creation and much more.',
#   '5 ',
#   'Sep 3 2021'],
#  ['Pela metade apenas os e-mails que envio pelo HubSpot ficam registrador o contrario não.',
#   '2 ',
#   'Sep 2 2021'],
#  ['It makes it very efficient to be able to work directly from HubSpot or from Gmail and switch as needed while missing nothing in the paper trail.',
#   '5 ',
#   'Sep 2 2021'],
# ...
#   '2 ',
#   'May 25 2021'],
#  ['HubSpot integration of Gmail is a definite improvement over regular Gmail. It is now part of my routine.',
#   '5 ',
#   'May 24 2021'],
#  ["it's free which is a maasive bonus it's helpful to be able to add leads immediately add a task or deal too. I wish it was possible to edit the details in gmail too like you can with the intercom + HubSpot integration",
#   '5 ',
#   'May 24 2021'],
#  ['I will rate poor for overall my experience with HubSpot and will not recommend to anyone My experience is literally worst with HubSpot tool',
#   '1 ',
#   'May 24 2021'],
#  ['Excelente de las mejores aplicaciones para trabajar muy intuitiva Fácil de entender y muy simple de usar Tiene herramientas gratuitas que apoyan mi trabajo',
#   '5 ',
#   'May 24 2021'],
#  ["Gmail works well I don't like that some of my messages from someone I get mail from on a daily basis is put in the Social or Promotions folders.",
#   '4 ',
#   'May 23 2021'],
#  ["It allows me to be more productive because I don't have to duplicate task and contact information",
#   '4 ',
#   'May 23 2021'],
#  ['Gmail is easiest to navigate easy it is to use it seems like anything you need is right there at your fingertips plus all the hundreds and thousands if not millions of extensions and this all makes it very smooth to run a business with.',
#   '2 ',
#   'May 22 2021'],
#  ['muy bien para la empresa es apropiado y logra que optimicemos nuestro tiempo y recursos.',
#   '5 ',
#   'May 21 2021'],
#  ['excelente herramienta para la elaboración de campañas y marketing digital recomiendo mucho la herramienta',
#   '5 ',
#   'May 21 2021'],
#  ['booohooo jhbouifhhjsvhn;aijupiwejhbchjbdxkjn yigtiuyhjikh yuguiyhoijh;juih yguighjki',
#   '3 ',
#   'May 21 2021'],
#  ['The integration features with Gmail allow me to gain the visibility and insights I need to make informed decisions as it relates to my prospects and their ultimate decision making. Putting together new documentation is a breeze.',
#   '5 ',
#   'May 21 2021'],
#  ['Es un correo mundial y muy funcional de fácil operación y ameno para enviar correos',
#   '4 ',
#   'May 21 2021'],
#  ['positivamente a afectado la operación de ventas de la empres. Pero tengo dudas de como aumenta el conteo de si se abrió el correo.',
#   '4 ',
#   'May 21 2021'],
#  ['The pop out on the right of the page needs to have a stop function it opens on every new email and takes up too much of the screen. I understand the benefits of it but it would be better to have the choice to use it or not. It takes up too much space on the page especially if you have the email page layout in two columns.',
#   '2 ',
#   'May 21 2021'],
#  ["impossibilitato a controllare il numero di aperture di un'email o dell'allegato all'interno come fossi su HubSpot funzionalità parziali",
#   '2 ',
#   'May 21 2021'],
#  ['Es läuft alles super gut und bin Super Zufrieden mit HubSpot +Gmail. Kann es nur Weiterempfehlen.',
#   '5 ',
#   'May 21 2021'],
#  ["HubSpot's GMail integration is pretty seamless and makes it incredibly convenient to log/track emails. It's particularly helpful when sending proposals to potential clients so we can see in real time when they are opening and know when to do appropriate follow-up.",
#   '4 ',
#   'May 20 2021'],
#  ['O Gmail funciona muito bem e junto com o HubSop só veio agregar valor! Facilidade para quem utiliza e muito bom para a empresa acompanhar o andamento do trabalho de seus funcionários.',
#   '5 ',
#   'May 20 2021'],
#  ['it helps me to store a bulk of data under one roof. no need of any extra crm',
#   '5 ',
#   'May 20 2021'],
#  ['Muy bien ha acelerado nuestro servicio y ha mejorado nuestra realcion con nuestros clientes',
#   '5 ',
#   'May 20 2021'],
#  ['Es universal confiable de facil acceso y compatible e',
#   '5 ',
#   'May 19 2021'],
#  ['Gmail ha sido una herramienta fundamental para el negocio pero la integración entre ambas plataformas deja mucho que desear. No es sencilla y en últimas resulta mejor buscar y enviar todo desde el mismo gmail y no HubSpot',
#   '3 ',
#   'May 19 2021'],
#  ["Works great except for those few times the emails don't get integrated. It allows me to send emails quicker without having to leave the platform.",
#   '3 ',
#   'May 19 2021'],
#  ['Muy bien se gestionan mejor lo contactos y las conversaciones y es muy fácil de usar',
#   '4 ',
#   'May 19 2021'],
#  ['As you can expect from an email service like Yahoo Gmail you can use it in Outlook or standalone mine is integrated into the company structure',
#   '4 ',
#   'May 19 2021'],
#  ['Excellent! It has made me well-organized! I feel confident stress-free & relaxed using it.',
#   '5 ',
#   'May 19 2021'],
#  ['Es una buena integración aunque en pocasiones se desconecta o por alguna razon no se vuelcan los emails al 100%  no es facil filtrar aquellos emails que no deben volcarse pero esto depende mas de HubSpot que de Gmails.',
#   '3 ',
#   'May 19 2021'],
#  ['La integración con HubSpot es muy básica y algunos correos no migran. (aun con la extensión prendida)',
#   '2 ',
#   'May 18 2021'],
#  ['Works efficiently and allows https://www.gend.co to quickly log gmail conversations and sales outreach with our contact records.',
#   '4 ',
#   'Mar 11 2021'],
#  ['somente sincroniza na primeira vez............................................................',
#   '1 ',
#   'Mar 2 2021'],
#  ['Esta funcionando de maravilla ya que me ha dado los soportes necesarios para interactuar con mis clientes.',
#   '5 ',
#   'Dec 21 2020'],
#  ["Works great with HubSpot. Can email from both gmail and HubSpot. The emails auto-log to the lead's profile in HubSpot and I can see if my prospect opened or clicked on any links. I can also use the templates sequences documents and my calendar links directly in Gmail.",
#   '5 ',
#   'Dec 21 2020'],
#  ["Basic options don't work. Some options like having your signature in your email have been disabled. So you cant have your signature. Which is kind of important when sending prospects emails. Not impressed at all",
#   '1 ',
#   'Dec 18 2020'],
#  ['It works fine when it stays logged in. Every other day I have to log back into the HubSpot tool.',
#   '2 ',
#   'Dec 17 2020'],
#  ["I have 3 different businesses that all use Gmail and I figured that since I have each one connected (in HubSpot) to a HubSpot account using that email address that it wouldn't send email from one account to another but it does. It doesn't matter what account you link in HubSpot if you are logged in to a specific HubSpot account (which it forces when you are in Gmail) then all other Gmail accounts open that have the plugin will send emails to that HubSpot account. This is very bad for me.",
#   '2 ',
#   'Dec 17 2020'],
#  ['Not well switching hosting to windows within the next quarter. For now we are not using the integration to its full potential.',
#   '3 ',
#   'Dec 17 2020'],
#  ['Para mi personalmente es muy practico. Para el trabajo muy útil y seguro.',
#   '5 ',
#   'Dec 17 2020'],
#  ['Easy to use suits well in the plateform and allow to me to have a general overview of all my activities',
#   '5 ',
#   'Dec 17 2020'],
#  ['既存の連絡先を全て潜在顧客として捉えることが可能となるので、 新しいビジネスチャンスにつながります。 また、操作も簡単ですので質の良いコンタクトをどんどん追加していけます',
#   '4 ',
#   'Dec 17 2020'],
#  ['Gmail und HubSpot funktionieren zusammen leider nicht gut. Mein Team und ich bitten daher dringenst um eine Integration in Mac Mail.',
#   '1 ',
#   'Dec 17 2020'],
#  ['I want the ability to choose how I log in and not get the feeling I have to use gmail. HubSpots is nice but needs improvement especially on who review my email great idea but not there yet',
#   '2 ',
#   'Dec 17 2020'],
#  ['funciona bien respuesta rápida fácil manejo en general. facilita el agendamiento.',
#   '5 ',
#   'Dec 17 2020'],
#  ['Es simplemente la mejor herramienta que hemos encontrado para gestionar los correos corporativos de la empresa',
#   '5 ',
#   'Dec 16 2020'],
#  ["I'd looked for a solution that allowed all the emails sent and received to a particular client to be stored in a neat and easy way along with notes call logs meetings etc to keep on track of everything. Gmail integrates with HubSpot seamlessly it even handles aliases pretty well which I wasn't expecting.",
#   '5 ',
#   'Dec 16 2020'],
#  ['Gmail integration is wonderful as I can see real time alerts regarding prospects opening and viewing emails sent. It is also adds ease of attaching marketing material to send to prospects.',
#   '5 ',
#   'Dec 16 2020'],
#  ['Muy bien me brinda una experiencia bastante agradable conectando funcionalidades de HubSpot en mi Gmail.',
#   '5 ',
#   'Dec 16 2020'],
#  ["great helps to track the emails easier and faster to log the customers' information in the HubSpot",
#   '5 ',
#   'Dec 16 2020'],
#  ["It's a great tool and one that we find very helpful both for ourselves and for our clients. However we run into issues with users who have multiple HubSpot accounts and wish to log different emails to different accounts. It would be great if there was a way within both gmail and outlook for you to toggle/select which HubSpot account you want to log each email to.",
#   '3 ',
#   'Dec 16 2020'],
#  ['Me es útil y práctico en todo lo que hago día a día puedo ver todo lo relacionado con mis actividades',
#   '4 ',
#   'Dec 15 2020'],
#  ['Excelente es muy útil su integración con Google Workspace. Hace el trabajo y seguimiento realmente práctico',
#   '5 ',
#   'Dec 14 2020'],
#  ['Perfectly we use it as our communication channel within the company and it works perfectly. As well as our communication channel with outbound leads we want to prospect and to evangelize with our solution. It has been really useful and we have managed to capture the interest of leading companies in different industries.',
#   '4 ',
#   'Dec 14 2020'],
#  ['Great additional to be able to track all incoming/outgoing emails for sales leads. It also automatically adds new contacts which is a huge time saver.',
#   '5 ',
#   'Dec 14 2020'],
#  ['Gmail is awesome. Cannot do without it! It stores my documents for any time referencing and is user friendly.',
#   '5 ',
#   'Dec 13 2020'],
#  ["Our company is having explosive growth. I love being able to see everything that I've sent my love having the templates I love Tracking my emails love the signature part is really nothing that I don't like about Gmail except that it doesn't have G mass and I love it together with hub spot so perfect I which hotspot was a little cheaper let the but it",
#   '5 ',
#   'Dec 12 2020'],
#  ['PARA MI HA SIDO UNA BUENA OPCIÓN CONTAR CON GMAIL POR QUE DE MI CORREO CORPORATIVO COPIO A ESTE Y LA INFORMACIÓN QUEDA RESPALDADA.',
#   '5 ',
#   'Dec 11 2020'],
#  ['Love the plug-in but it needs to support creating new tickets too. Currently it only allows linking to existing tickets. There should be an option to create a new ticket as well that is linked to the email and the contact.',
#   '5 ',
#   'Dec 11 2020'],
#  ['In my opinion there could be more documentation related to the usage of the extension as it has excellent features and functions that can be discovered by using the tool but not from a document outlining them for people who have never had the chance to experiment with it.',
#   '5 ',
#   'Dec 10 2020'],
#  ["Gmail is great. It is a much better solution for email then competitors that rely on POP or IMAP or Outlook/Exchange. The big problem with the integration of HS with Gmail is that there is still a lot of manual effort to bring data into HS. This isn't state of the art compared to other CRM tools on the market.",
#   '3 ',
#   'Dec 10 2020'],
#  ['Gmail isolated is very good and the HubSpot tracking is less advanced when it comes to overview of tracking per email in G-mail/HubSpot extension and total view of campaigns etc in HubSpot - have a look at Mixmax for improvement suggestions ;-). I would strongly recommend to allow to import stand-alone mailing list from .CSV in HubSpot sequences.',
#   '3 ',
#   'Dec 10 2020'],
#  ['Really helpful and saving time. All organised well in one place and the mail tracking works really good',
#   '5 ',
#   'Dec 10 2020'],
#  ['4. La explicación es pesima en un espectacular producto. Es soportable pero no deberia permitirse. En general la explicaciones son deficiente y la curva es dolorosa',
#   '5 ',
#   'Dec 9 2020'],
#  ['My team is able to see contact activities and reach out or not to specific contact according to my previous messages. Moreover the widget for Gmail helps me speed up the writing process by selecting snippets and templates directly into Gmail.',
#   '5 ',
#   'Dec 7 2020'],
#  ['super tous les mails sont automatiquement envoyés sur HubSpot à partir de ma messagerie',
#   '5 ',
#   'Dec 2 2020'],
#  ["it's working great easy to use and working as I intended. Only that it's actually add-on is a bit off-putting but not terrible",
#   '4 ',
#   'Nov 26 2020'],
#  ['I would really like the HubSpot extension to work but had to disable until the problem can be overcome. I use the mail search function a lot.',
#   '2 ',
#   'Oct 9 2020'],
#  ['1) I would like HubSpot to retire the legacy Chrome Extension in favor of a Google G-Suite Gmail Addon. The extension sits on top of the native UI overlaying other components and never works quite right frequently causing issues when trying to send messages through Gmail. 2) When you publish the addon please make sure it has the ability to create tickets. One use-case for this would be to click on a HubSpot addon in Gmail to forward messages that were sent to individual address (instead of the support address) and this functionality would allow us to create a ticket on behalf of the original sender.',
#   '3 ',
#   'Sep 26 2020'],
#  ['There is one big problem with Gmail-HubSpot arrangement- It is not possible to sync contacts. It would be very convenient to have all the contacts I add to HubSpot populate in Gmail because it is very annoying to have contacts in two different places.',
#   '3 ',
#   'Aug 3 2020'],
#  ["Gmail seems to work well. HubSpot email tracking doesn't work that well. email tracking within HubSpot is atrocious as it doesn't handle contacts tied to multiple deals. it simply guesses and is a huge time suck to clean up deals that have multiple contacts or contacts with multiple deals associated with him/her. This takes so much time to clean this up and get it sorted out.",
#   '2 ',
#   'Jul 15 2020'],
#  ['The HubSpot Gmail integration does not meet my expectations at all. This is the capability I like least about HubSpot and the only thing I really miss about our previous CRM system.',
#   '2 ',
#   'Jul 14 2020'],
#  ['And even the non-techies like me can get it working so that emails log to the HubSpot CRM easily.',
#   '5 ',
#   'Jul 14 2020'],
#  ['Working fine but HubSpot integration is very intermittent. Sometimes works mostly not. Also the way HubSpot displays email threads is so annoying it’s almost a showstopper. You click on an email to some more and it leaps off in an entirely disorienting way somehow positioning the thread upside down so you have no idea what order to read anything in. It sucks',
#   '2 ',
#   'Jul 13 2020'],
#  ['yet to see its benefits figuring out how to leverage the integration and with time we hope to know more about it.',
#   '5 ',
#   'Jul 13 2020'],
#  ['Logging/Tracking Gmail activity as a sales rep goes saves the rep time and provide "activity" visibility across our company.',
#   '4 ',
#   'Jul 13 2020'],
#  ['The HubSpot-Gmail integration makes it easy to engage and serve clients. All the email functions (snippets templates meetings and sequences) are available in the familiar Gmail interface.',
#   '5 ',
#   'Jul 13 2020'],
#  ['If I have HubSpot integration turned on with my business account and accessed my personal account any email i send from the personal account the HubSpot plugin picks it up and logs it in HubSpot or sends it to the default email address of the business. This is a major security flaw.',
#   '1 ',
#   'Jul 13 2020']]

# %%
review = comments[5][0].lower()
print (review)
blob = TextBlob(review)
sentiment = blob.sentiment
print (sentiment)
# Out:
# funciona muy bien. estable y muy confiable. utilizamos la suite para toda la empresa con excelentes resultados
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
TextBlob("bonjour").translate(to="en")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\Users\THOMAS~1.SCA\AppData\Local\Temp/ipykernel_12628/3012778039.py in <module>
# ----> 1 TextBlob("bonjour").translate(to="en")
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     559         if http_err:
#     560             args = (dict, 'default', 'http_error_default') + orig_args
# --> 561             return self._call_chain(*args)
#     562
#     563 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     639 class HTTPDefaultErrorHandler(BaseHandler):
#     640     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     642
#     643 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
polarities = []
subjectivities = []
for doc in comments: 
    blob = TextBlob(doc[0])
    polarity = blob.sentiment.polarity
    subjectivity = blob.sentiment.subjectivity
    polarities.append(polarity)
    subjectivities.append(subjectivity)

# %%
plt.scatter (polarities, subjectivities)
plt.xlabel ("polarities")
plt.ylabel ("subjectivities")
plt.title ("subjectivities as a function of polarities of reviews.io reviews")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data ["Subjectivity"] = subjectivities 
data ["Polarity"] = polarities
full_data = data.rename(columns={'REVIEW': 'Review', 'RATING': 'Rating', 'DATE': 'Date'})
full_data
# Out:
#                                                 Review   Rating         Date  \
# 0    The integration is extremely easy to use and h...        4  Jan 11 2022
# 1    Yes makes it more difficult HubSpot help mostl...        1  Jan 11 2022
# 2    It works very well and integrates well with my...        5  Jan 10 2022
# 3    I use Missive to send email but they show as s...        2  Jan 10 2022
# 4    did not want every email to be in HubSpot but ...        1   Jan 7 2022
# ..                                                 ...      ...          ...
# 630  Working fine but HubSpot integration is very i...        2  Jul 13 2020
# 631  yet to see its benefits figuring out how to le...        5  Jul 13 2020
# 632  Logging/Tracking Gmail activity as a sales rep...        4  Jul 13 2020
# 633  The HubSpot-Gmail integration makes it easy to...        5  Jul 13 2020
# 634  If I have HubSpot integration turned on with m...        1  Jul 13 2020
#
#      Subjectivity  Polarity
# 0        0.833333  0.433333
# 1        0.440000  0.080000
# 2        0.200000  0.100000
# 3        0.000000  0.000000
# 4        0.000000  0.000000
# ..            ...       ...
# 630      0.489236 -0.048611
# 631      0.500000  0.500000
# 632      0.000000  0.000000
# 633      0.577778  0.402778
# 634      0.366667  0.020833
#
# [635 rows x 5 columns]

# %%
full_data.to_csv('HubspotFinal.csv', index=False)

# %%
pol_mean = full_data['POLARITY'].mean()
sub_mean = full_data['SUBJECTIVITY'].mean()
print ("average polarity is:")
print(pol_mean)
print ("average subjectvitiy is:")
print (sub_mean)
# Out:
# average polarity is:
# 0.15714942317713007
# average subjectvitiy is:
# 0.34680382155025324
