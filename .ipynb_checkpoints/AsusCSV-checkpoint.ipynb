# %%
import nltk
import numpy as np
import csv
import pandas as pd
import seaborn as sns
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import matplotlib
from textblob import TextBlob
from matplotlib import pyplot as plt
from dateutil import parser
import dataparser
from datetime import datetime
# import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
stop_words = set(stopwords.words("english"))

# %%
data = pd.read_csv('AsusReviewdata.csv')
print ("Original 'AsusReviewdata.csv' CSV Data: \n")
data.columns=['Index','Date','Review','Rating']
del data['Index']
data
# Out:
# Original 'AsusReviewdata.csv' CSV Data:
#                 Date                                             Review Rating
# 0      8/9/21 2:54PM  Asus is a terrible and horrible company.\nYour...    neg
# 1      7/1/21 1:34PM  It is my recommendation not to buy ASUS produc...    neg
# 2     6/17/21 9:14PM  Hello,\nI bought my asus rog strix laptop 2mon...    neg
# 3     5/17/21 6:06AM  I purchased a monitor that was 144HZ. Never ab...    neg
# 4    12/10/20 4:13PM  Whether you throw your money in a garbage can ...    neg
# ..               ...                                                ...    ...
# 546   10/9/17 3:19PM  To whom in may concern.\n\nThis morning, after...    pos
# 547  10/8/17 11:58PM  Damir F. gave very positive experience on [CAS...    pos
# 548   10/4/17 4:39PM  Alfredo was knowledgeable and friendly, helped...    pos
# 549   9/29/17 9:48AM  Jowayne B. was awesome. was just a pleasure to...    pos
# ...

# %%
comments = []
with open ("AsusReviewdata.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        comments.append(row)
        print (row)
# Out:
# ['0', '9/6/21 1:25AM', "Bought an ASUS netbook last September 12, 2021, in less than a year the netbook will not turn on when on battery mode even if its 100 percent fully charge, when you remove the charger it will turn off even if its 100 percent fully charge, it will only turn on when its plugged in. Already sent it to the service center and still they are looking into the problem. I emailed ASUS and requested for a replacement and hopefully they will respond to my request. Its my first time to use ASUS and with only less than a year felt bad to encounter such issues which i have not experienced with the other brands. It's disappointing.", 'neg']
# ...

# %%
del comments [0]

# %%
review = comments[0][2].lower()
print (review)
blob = TextBlob(review)
sentiment = blob.sentiment
print (sentiment)
# Out:
# asus is a terrible and horrible company.
# your information is not secure as they have people working from home.
# the last representative hung on me.
#
# tammy and zack are the ceo office, but their phone numbers change without notice.
# i fully regret ever doing any business with asus.
# they don't follow-up.
# i'm still waiting for my buy back money
# which on one follow up.
# calling them is a dead end.
# Sentiment(polarity=-0.4000000000000001, subjectivity=0.5111111111111112)

# %%
polarities = []
subjectivities = []
for doc in comments: 
    blob = TextBlob(doc[2])
    polarity = blob.sentiment.polarity
    subjectivity = blob.sentiment.subjectivity
    polarities.append(polarity)
    subjectivities.append(subjectivity)

# %%
plt.scatter (polarities, subjectivities)
plt.xlabel ("polarities")
plt.ylabel ("subjectivities")
plt.title ("subjectivities as a function of polarities of Asus reviews")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data ["Subjectivity"] = subjectivities 
data ["Polarity"] = polarities
full_data = data
full_data
# Out:
#                 Date                                             Review  \
# 0      8/9/21 2:54PM  Asus is a terrible and horrible company.\nYour...
# 1      7/1/21 1:34PM  It is my recommendation not to buy ASUS produc...
# 2     6/17/21 9:14PM  Hello,\nI bought my asus rog strix laptop 2mon...
# 3     5/17/21 6:06AM  I purchased a monitor that was 144HZ. Never ab...
# 4    12/10/20 4:13PM  Whether you throw your money in a garbage can ...
# ..               ...                                                ...
# 546   10/9/17 3:19PM  To whom in may concern.\n\nThis morning, after...
# 547  10/8/17 11:58PM  Damir F. gave very positive experience on [CAS...
# 548   10/4/17 4:39PM  Alfredo was knowledgeable and friendly, helped...
# 549   9/29/17 9:48AM  Jowayne B. was awesome. was just a pleasure to...
# 550  9/27/17 10:32AM  I called , and Alfreo W was superb. He went wa...
#
#     Rating  Subjectivity  Polarity
# 0      neg      0.511111 -0.400000
# ...

# %%
pol_mean = full_data['Polarity'].mean()
sub_mean = full_data['Subjectivity'].mean()
print ("average polarity is:")
print(pol_mean)
print ("average subjectvitiy is:")
print (sub_mean)
# Out:
# average polarity is:
# 0.14352345690612034
# average subjectvitiy is:
# 0.4456123175675247

# %%
full_data.to_csv('AsusFinal.csv', index=False)
